# %% [markdown]
# ## Code Modules & Functions

# %%
import numpy as np,pandas as pd,pylab as pl
import h5py,tensorflow as tf
from tensorflow import image as timg
import tensorflow.keras.layers as tfkl
import tensorflow.keras.applications as tfka

# %%
def resize_info(x_train,y_train,
                x_test,y_test,pixels):
    x_train=np.array(timg.resize(x_train,[pixels,pixels]))
    x_test=np.array(timg.resize(x_test,[pixels,pixels]))
    N=len(y_train); shuffle_ids=np.arange(N)
    np.random.RandomState(12).shuffle(shuffle_ids)
    x_train,y_train=x_train[shuffle_ids],y_train[shuffle_ids]
    N=len(y_test); shuffle_ids=np.arange(N)
    np.random.RandomState(23).shuffle(shuffle_ids)
    x_test,y_test=x_test[shuffle_ids],y_test[shuffle_ids]
    n=int(len(x_test)/2)
    x_valid,y_valid=x_test[:n],y_test[:n]
    x_test,y_test=x_test[n:],y_test[n:]
    df=pd.DataFrame([[x_train.shape,x_valid.shape,x_test.shape],
                     [x_train.dtype,x_valid.dtype,x_test.dtype],
                     [y_train.shape,y_valid.shape,y_test.shape],
                     [y_train.dtype,y_valid.dtype,y_test.dtype]],
                    columns=['train','valid','test'],
                    index=['image shape','image type',
                           'label shape','label type'])
    display(df)    
    return [[x_train,x_valid,x_test],
            [y_train,y_valid,y_test]]
def display_examples(x,y):
    n=np.random.randint(1,50)
    fig=pl.figure(figsize=(11,4))
    for i in range(n,n+5):
        ax=fig.add_subplot(1,5,i-n+1,\
        xticks=[],yticks=[],title=y[i])
        ax.imshow(x[i]); 
    pl.show()

# %% [markdown]
# ## Data

# %%
pixels=64
fpath='../input/tf-cats-vs-dogs/'
f='CatDogImages.h5'
f=h5py.File(fpath+f,'r')
keys=list(f.keys()); print(keys)
x_test=np.array(f[keys[0]])
y_test=np.array(f[keys[1]]).reshape(-1)
x_train=np.array(f[keys[2]])
y_train=np.array(f[keys[3]]).reshape(-1)
[[x_train,x_valid,x_test],
 [y_train,y_valid,y_test]]=\
resize_info(x_train,y_train,x_test,y_test,pixels)
# Out:
# ['test_images', 'test_labels', 'train_images', 'train_labels']
#                           train              valid               test
# image shape  (18610, 64, 64, 3)  (2326, 64, 64, 3)  (2326, 64, 64, 3)
# image type              float32            float32            float32
# label shape            (18610,)            (2326,)            (2326,)
# label type                int32              int32              int32

# %%
display_examples(x_valid,y_valid)

# %% [markdown]
# ## VGG16

# %%
def VGG16L(pixels):
    base_model=tfka.VGG16(include_top=False,
                          weights='imagenet',
                          input_shape=(pixels,pixels,3))
    x=base_model.output
    x=tfkl.GlobalAveragePooling2D()(x)
    x=tfkl.Dense(1024)(x)
    x=tfkl.LeakyReLU(alpha=.02)(x)
    y=tfkl.Dense(1,activation=tf.nn.sigmoid)(x)
    model=tf.keras.Model(inputs=base_model.input,outputs=y)
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
fw='weights.best.hdf5'
def cb(fw):
    early_stopping=tf.keras.callbacks\
    .EarlyStopping(monitor='val_loss',patience=20,verbose=2)
    checkpointer=tf.keras.callbacks\
    .ModelCheckpoint(filepath=fw,save_best_only=True,verbose=2)
    lr_reduction=tf.keras.callbacks\
    .ReduceLROnPlateau(monitor='val_loss',verbose=2,
                       patience=5,factor=.8)
    return [checkpointer,early_stopping,lr_reduction]
def history_plot(fit_history):
    pl.figure(figsize=(12,10)); pl.subplot(211)
    keys=list(fit_history.history.keys())[0:4]
    pl.plot(fit_history.history[keys[0]],
            color='slategray',label='train')
    pl.plot(fit_history.history[keys[2]],
            color='#4876ff',label='valid')
    pl.xlabel("Epochs"); pl.ylabel("Loss")
    pl.legend(); pl.grid()
    pl.title('Loss Function')     
    pl.subplot(212)
    pl.plot(fit_history.history[keys[1]],
            color='slategray',label='train')
    pl.plot(fit_history.history[keys[3]],
            color='#4876ff',label='valid')
    pl.xlabel("Epochs"); pl.ylabel("Accuracy")    
    pl.legend(); pl.grid()
    pl.title('Accuracy'); pl.show()

# %%
model=VGG16L(pixels)
history=model.fit(x=x_train,y=y_train,
                  batch_size=128,epochs=20,
                  callbacks=cb(fw),
                  validation_data=(x_valid,y_valid))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Epoch 1/20
# 146/146 [==============================] - ETA: 0s - loss: 0.8032 - accuracy: 0.5432
# Epoch 00001: val_loss improved from inf to 0.65778, saving model to weights.best.hdf5
# 146/146 [==============================] - 14s 94ms/step - loss: 0.8032 - accuracy: 0.5432 - val_loss: 0.6578 - val_accuracy: 0.6139 - lr: 0.0010
# Epoch 2/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.6032 - accuracy: 0.6728
# Epoch 00002: val_loss improved from 0.65778 to 0.48369, saving model to weights.best.hdf5
# 146/146 [==============================] - 13s 88ms/step - loss: 0.6030 - accuracy: 0.6730 - val_loss: 0.4837 - val_accuracy: 0.7704 - lr: 0.0010
# Epoch 3/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.4130 - accuracy: 0.8106
# Epoch 00003: val_loss improved from 0.48369 to 0.35802, saving model to weights.best.hdf5
# 146/146 [==============================] - 13s 88ms/step - loss: 0.4128 - accuracy: 0.8109 - val_loss: 0.3580 - val_accuracy: 0.8396 - lr: 0.0010
# Epoch 4/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.3169 - accuracy: 0.8664
# Epoch 00004: val_loss improved from 0.35802 to 0.28683, saving model to weights.best.hdf5
# 146/146 [==============================] - 13s 89ms/step - loss: 0.3171 - accuracy: 0.8664 - val_loss: 0.2868 - val_accuracy: 0.8801 - lr: 0.0010
# Epoch 5/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.2535 - accuracy: 0.8967
# Epoch 00005: val_loss did not improve from 0.28683
# 146/146 [==============================] - 12s 85ms/step - loss: 0.2537 - accuracy: 0.8967 - val_loss: 0.3077 - val_accuracy: 0.8581 - lr: 0.0010
# Epoch 6/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.2077 - accuracy: 0.9155
# Epoch 00006: val_loss improved from 0.28683 to 0.22175, saving model to weights.best.hdf5
# 146/146 [==============================] - 13s 88ms/step - loss: 0.2077 - accuracy: 0.9156 - val_loss: 0.2217 - val_accuracy: 0.9157 - lr: 0.0010
# Epoch 7/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.9334
# Epoch 00007: val_loss did not improve from 0.22175
# 146/146 [==============================] - 12s 85ms/step - loss: 0.1668 - accuracy: 0.9334 - val_loss: 0.2397 - val_accuracy: 0.9028 - lr: 0.0010
# Epoch 8/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.1378 - accuracy: 0.9447
# Epoch 00008: val_loss improved from 0.22175 to 0.21024, saving model to weights.best.hdf5
# 146/146 [==============================] - 13s 88ms/step - loss: 0.1378 - accuracy: 0.9447 - val_loss: 0.2102 - val_accuracy: 0.9192 - lr: 0.0010
# Epoch 9/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.1021 - accuracy: 0.9591
# Epoch 00009: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.1020 - accuracy: 0.9591 - val_loss: 0.2442 - val_accuracy: 0.9140 - lr: 0.0010
# Epoch 10/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0890 - accuracy: 0.9664
# Epoch 00010: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0889 - accuracy: 0.9664 - val_loss: 0.2555 - val_accuracy: 0.9089 - lr: 0.0010
# Epoch 11/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0777 - accuracy: 0.9698
# Epoch 00011: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0776 - accuracy: 0.9699 - val_loss: 0.2315 - val_accuracy: 0.9218 - lr: 0.0010
# Epoch 12/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0553 - accuracy: 0.9793
# Epoch 00012: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0553 - accuracy: 0.9793 - val_loss: 0.2476 - val_accuracy: 0.9273 - lr: 0.0010
# Epoch 13/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0562 - accuracy: 0.9794
# Epoch 00013: val_loss did not improve from 0.21024
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 146/146 [==============================] - 13s 86ms/step - loss: 0.0561 - accuracy: 0.9794 - val_loss: 0.2752 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 14/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9859
# Epoch 00014: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0382 - accuracy: 0.9860 - val_loss: 0.2765 - val_accuracy: 0.9239 - lr: 8.0000e-04
# Epoch 15/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0268 - accuracy: 0.9907
# Epoch 00015: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0268 - accuracy: 0.9907 - val_loss: 0.3220 - val_accuracy: 0.9192 - lr: 8.0000e-04
# Epoch 16/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9920
# Epoch 00016: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0206 - accuracy: 0.9920 - val_loss: 0.4399 - val_accuracy: 0.8960 - lr: 8.0000e-04
# Epoch 17/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0348 - accuracy: 0.9880
# Epoch 00017: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0347 - accuracy: 0.9881 - val_loss: 0.3052 - val_accuracy: 0.9157 - lr: 8.0000e-04
# Epoch 18/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 0.9920
# Epoch 00018: val_loss did not improve from 0.21024
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 146/146 [==============================] - 13s 86ms/step - loss: 0.0224 - accuracy: 0.9920 - val_loss: 0.3580 - val_accuracy: 0.9183 - lr: 8.0000e-04
# Epoch 19/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0108 - accuracy: 0.9965
# Epoch 00019: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.5021 - val_accuracy: 0.9136 - lr: 6.4000e-04
# Epoch 20/20
# 145/146 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9957
# Epoch 00020: val_loss did not improve from 0.21024
# 146/146 [==============================] - 12s 85ms/step - loss: 0.0113 - accuracy: 0.9957 - val_loss: 0.4236 - val_accuracy: 0.9183 - lr: 6.4000e-04

# %%
history_plot(history)

# %%
model.load_weights(fw)
model.evaluate(x_test,y_test)
# Out:
# 73/73 [==============================] - 1s 11ms/step - loss: 0.2235 - accuracy: 0.9149
# [0.22352325916290283, 0.914875328540802]
