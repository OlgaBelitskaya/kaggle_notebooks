# %%
# %run ../input/python-recipes/dhtml.py
dhtml('Code Modules & Settings',c10,f2,fs7)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     Code Modules & Settings</h1>

# %%
import os,numpy as np,pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from skimage import io
from IPython.display import display

# %%
dhtml('Interactive Data Presentation',c10,f2,fs7)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     Interactive Data Presentation</h1>

# %%
def pd_style(file_path,file,num):
    table_style=\
    [dict(selector="th",
          props=[("font-size","12pt")]),
     dict(selector="td",
          props=[("padding","0em 0em")]),
     dict(selector="th:hover",
          props=[("color","slategray"),
                 ("font-size","16pt")]),
     dict(selector="tr:hover td:hover",
          props=[("max-width","200px"),
                 ("color","darkslategray"),
                 ("font-color","slategray"),
                 ("font-size","16pt")])]
    df=pd.read_csv(file_path+file)
    display(df.head(num).T.style\
              .background_gradient("cool",axis=1)\
              .set_properties(**{"max-width":"80px",
                                 "font-size":"1pt"})\
              .set_caption(dhtml("Table Exploration",
                                 c10,f2,fs7))\
              .set_precision(2)\
              .set_table_styles(table_style))

# %%
file_path1='../input/image-examples-for-mixed-styles/'
file1='beethoven.csv'; num1=12
pd_style(file_path1,file1,num1)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     Table Exploration</h1>
# <style  type="text/css" >
#     #T_90cc8716_1823_11eb_9e28_0242ac130202 th {
#           font-size: 12pt;
#     }    #T_90cc8716_1823_11eb_9e28_0242ac130202 td {
#           padding: 0em 0em;
#     }    #T_90cc8716_1823_11eb_9e28_0242ac130202 th:hover {
#           color: slategray;
#           font-size: 16pt;
#     }    #T_90cc8716_1823_11eb_9e28_0242ac130202 tr:hover td:hover {
#           max-width: 200px;
#           color: darkslategray;
#           font-color: slategray;
#           font-size: 16pt;
#     }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col0 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col1 {
#             background-color:  #9e61ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col2 {
#             background-color:  #8f70ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col3 {
#             background-color:  #fa05ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col4 {
#             background-color:  #8976ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col5 {
#             background-color:  #f40bff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col6 {
#             background-color:  #7b84ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col7 {
#             background-color:  #e817ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col8 {
#             background-color:  #3fc0ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col9 {
#             background-color:  #cc33ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col10 {
#             background-color:  #00ffff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row0_col11 {
#             background-color:  #8d72ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col0 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col1 {
#             background-color:  #e01fff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col2 {
#             background-color:  #a758ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col3 {
#             background-color:  #c936ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col4 {
#             background-color:  #7e81ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col5 {
#             background-color:  #a857ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col6 {
#             background-color:  #649bff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col7 {
#             background-color:  #8f70ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col8 {
#             background-color:  #23dcff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col9 {
#             background-color:  #619eff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col10 {
#             background-color:  #00ffff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row1_col11 {
#             background-color:  #3ec1ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col0 {
#             background-color:  #ee11ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col1 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col2 {
#             background-color:  #d42bff;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col3 {
#             background-color:  #bd42ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col4 {
#             background-color:  #b24dff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col5 {
#             background-color:  #9966ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col6 {
#             background-color:  #936cff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col7 {
#             background-color:  #728dff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col8 {
#             background-color:  #50afff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col9 {
#             background-color:  #3dc2ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col10 {
#             background-color:  #09f6ff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_90cc8716_1823_11eb_9e28_0242ac130202row2_col11 {
#             background-color:  #00ffff;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }</style><table id="T_90cc8716_1823_11eb_9e28_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th clas

# %%
dhtml('Interactive Image Presentation',c10,f2,fs7)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     Interactive Image Presentation</h1>

# %%
# %%writefile plotly_images.py
import os,numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from skimage import io
def plotly_images(file_path):
    files=os.listdir(file_path)
    numbers=np.random.randint(1,len(files),5)
    fig=make_subplots(1,5); steps=[]
    for step in np.arange(1,6,1):
        img=io.imread(file_path+files[numbers[step-1]])
        img=img[:,:,:3]
        fig.add_trace(go.Image(z=img),1,step)
        fig.data[step-1].visible=False
    fig.data[0].visible=True
    for i in range(len(fig.data)):
        step=dict(method="update",
                  args=[{"visible":[False]*len(fig.data)}])
        step["args"][0]["visible"][i]=True
        steps.append(step)
    sliders=[dict(active=0,pad={"t":5},steps=steps)]
    fig.update_layout(width=500,height=250,
                      sliders=sliders,
                      template='plotly_dark',
                      title_text="Image Examples",
                      title_font=dict(size=12))
    fig.update_xaxes(showticklabels=False)\
    .update_yaxes(showticklabels=False)
    return fig
# Out:
# Writing plotly_images.py

# %%
# %run plotly_images.py
file_path2='../input/flower-color-images/flowers/flowers/'
fig=plotly_images(file_path2)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="5e8b2ab6-e57b-4dc5-95c0-b0184db67755" class="plotly-graph-div" style="height:250px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5e8b2ab6-e57b-4dc5-95c0-b0184db67755")) {
#                     Plotly.newPlot(
#                         '5e8b2ab6-e57b-4dc5-95c0-b0184db67755',
#                         [{"type": "image", "visible": true, "xaxis": "x", "yaxis": "y", "z": [[[54, 111, 26], [51, 113, 27], [54, 116, 30], [59, 120, 33], [65, 122, 37], [68, 123, 41], [69, 125, 44], [70, 127, 45], [69, 127, 45], [67, 126, 42], [63, 124, 37], [59, 121, 32], [59, 122, 32], [59, 116, 32], [55, 101, 27], [54, 90, 23], [57, 90, 24], [66, 103, 34], [70, 112, 40], [71, 119, 44], [74, 124, 47], [72, 125, 46], [70, 126, 45], [68, 126, 42], [66, 124, 39], [65, 123, 39], [65, 124, 38], [65, 124, 38], [65, 125, 38], [65, 126, 38], [65, 125, 35], [64, 124, 34], [63, 124, 33], [62, 124, 31], [60, 124, 29], [59, 124, 28], [58, 122, 27], [55, 119, 27], [53, 117, 26], [53, 109, 26], [50, 93, 25], [43, 71, 23], [36, 50, 23], [33, 38, 24], [32, 33, 25], [31, 35, 22], [36, 49, 21], [46, 70, 26], [59, 91, 30], [70, 107, 31], [75, 116, 30], [72, 117, 28], [68, 115, 27], [69, 118, 28], [73, 124, 29], [77, 129, 30], [79, 130, 30], [79, 129, 29], [76, 126, 28], [73, 121, 27], [70, 116, 25], [68, 111, 25], [65, 106, 25], [63, 99, 25], [58, 87, 25], [52, 74, 27], [48, 62, 29], [42, 50, 29], [39, 41, 28], [38, 38, 28], [38, 38, 30], [38, 38, 32], [37, 37, 30], [37, 37, 29], [37, 37, 28], [36, 36, 28], [36, 36, 28], [38, 37, 29], [41, 39, 31], [41, 40, 32], [39, 38, 31], [36, 36, 29], [33, 33, 26], [32, 34, 25], [34, 41, 27], [40, 51, 30], [48, 62, 32], [59, 77, 35], [69, 91, 39], [78, 98, 42], [83, 101, 44], [79, 96, 43], [71, 87, 40], [65, 78, 37], [64, 76, 38], [65, 78, 40], [69, 81, 41], [75, 89, 45], [83, 98, 50], [91, 108, 57], [94, 112, 61], [88, 104, 58], [77, 91, 53], [70, 85, 51], [69, 84, 50], [68, 82, 48], [69, 79, 48], [70, 75, 50], [66, 67, 45], [57, 55, 39], [50, 48, 35], [46, 44, 33], [44, 42, 32], [42, 41, 32], [41, 41, 32], [41, 41, 32], [41, 41, 32], [41, 41, 32], [40, 40, 31], [39, 39, 29], [38, 37, 28], [38, 35, 27], [38, 36, 28], [39, 37, 29], [40, 37, 29], [39, 38, 29], [39, 38, 30], [42, 41, 32]], [[57, 115, 26], [54, 115, 27], [53, 114, 29], [54, 116, 30], [57, 118, 31], [60, 120, 33], [64, 122, 36], [66, 125, 38], [64, 125, 38], [61, 123, 35], [57, 121, 32], [54, 118, 28], [54, 116, 27], [53, 108, 27], [52, 97, 24], [54, 93, 23], [61, 100, 27], [72, 116, 41], [77, 125, 48], [77, 129, 51], [77, 129, 50], [72, 125, 45], [69, 124, 43], [67, 123, 42], [66, 123, 40], [66, 125, 40], [67, 125, 40], [67, 126, 41], [69, 127, 41], [69, 128, 41], [69, 128, 41], [68, 127, 40], [66, 126, 38], [64, 126, 35], [62, 125, 32], [61, 125, 31], [61, 125, 31], [59, 125, 31], [58, 124, 29], [58, 120, 27], [55, 108, 24], [50, 92, 22], [41, 70, 21], [33, 48, 22], [32, 36, 25], [33, 37, 24], [39, 49, 25], [46, 67, 28], [54, 83, 30], [62, 95, 32], [64, 99, 30], [59, 98, 27], [60, 100, 26], [67, 110, 29], [75, 120, 32], [79, 128, 32], [83, 133, 32], [82, 131, 30], [78, 125, 28], [73, 117, 27], [69, 109, 26], [64, 102, 26], [60, 94, 26], [55, 84, 25], [49, 70, 25], [45, 59, 27], [42, 50, 28], [38, 41, 27], [36, 36, 26], [37, 37, 26], [39, 39, 30], [40, 39, 33], [39, 39, 30], [39, 39, 29], [38, 38, 29], [38, 38, 29], [38, 39, 29], [41, 40, 30], [44, 41, 33], [44, 41, 33], [42, 40, 31], [38, 38, 29], [35, 35, 27], [33, 36, 26], [34, 39, 25], [36, 43, 26], [39, 50, 26], [47, 61, 30], [57, 74, 36], [69, 84, 40], [75, 87, 42], [71, 84, 41], [66, 78, 39], [60, 71, 36], [56, 67, 34], [60, 71, 37], [68, 80, 41], [75, 88, 45], [81, 94, 49], [86, 101, 55], [88, 102, 59], [83, 96, 57], [74, 87, 54], [70, 84, 55], [70, 84, 53], [65, 78, 46], [60, 69, 41], [59, 61, 40], [57, 55, 39], [54, 50, 37], [51, 47, 36], [49, 45, 35], [46, 44, 34], [42, 42, 33], [41, 40, 31], [39, 39, 30], [38, 38, 29], [39, 39, 30], [39, 39, 30], [39, 39, 29], [38, 38, 28], [39, 36, 28], [39, 36, 28], [40, 37, 29], [41, 38, 30], [39, 38, 29], [39, 39, 29], [41, 41, 32]], [[63, 120, 27], [63, 117, 29], [57, 114, 31], [53, 113, 31], [53, 115, 30], [55, 118, 28], [59, 121, 29], [61, 123, 32], [60, 123, 33], [57, 121, 32], [54, 119, 29], [50, 115, 25], [44, 108, 21], [41, 96, 18], [ ...

# %%
dhtml('Interactive Charts',c10,f2,fs7)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     Interactive Charts</h1>

# %%
file='../input/html-recipes/glinechart.html'
with open(file,'r') as f:
    html_str=f.read()#.replace('\n','') 
    f.close()
HTML(html_str)
# Out:
# <script type='text/javascript'
#         src='https://www.gstatic.com/charts/loader.js'></script>
# <div id='div004' style='width:500px; height:500px;'></div>
# <script>
# function get_int(xmin,xmax) {
#     return Math.floor(Math.random()*(xmax-xmin+1))+xmin;};
# function get_color(k) {
#     return '#'+get_int(10*k,255).toString(16)+
#             get_int(10*k,255).toString(16)+
#             get_int(10*k,255).toString(16);};
# function fx(a,b,c,q,n,t,k) {
#     var x1=Math.cos(Math.PI*t/n+k*Math.PI/q),
#         x2=Math.cos(a*Math.PI*t/n+k*Math.PI/q),
#         x3=Math.cos(b*Math.PI*t/n+k*Math.PI/q),
#         x4=Math.cos(c*Math.PI*t/n+k*Math.PI/q);
#     return x1+x2+x3+x4};
# function fy(a,b,c,q,n,t,k) {
#     var y1=Math.sin(Math.PI*t/n+k*Math.PI/q),
#         y2=Math.sin(a*Math.PI*t/n+k*Math.PI/q),
#         y3=Math.sin(b*Math.PI*t/n+k*Math.PI/q),
#         y4=Math.sin(c*Math.PI*t/n+k*Math.PI/q);
#     return y1+y2+y3+y4};
# function ar(a,b,c,q,n,k) {
#     return Array(2*n+1).fill(k).map((k,t)=>
#           [fx(a,b,c,q,n,t,k),fy(a,b,c,q,n,t,k)]);};
# google.charts.load('current',{'packages':['corechart']});
# google.charts.setOnLoadCallback(drawChart);
# function drawChart() {
#     var a=get_int(5,9),b=get_int(10,14),c=get_int(15,19),
#         q=get_int(3,6),n=get_int(4,16);
#     var xy=ar(a,b,c,q,n,1); xy.unshift(['x',[a,b,c,q,n].toString()]);
#     for (var k=2; k<2*q+2; k++) {xy=xy.concat(ar(a,b,c,q,n,k));};
#     var data=google.visualization.arrayToDataTable(xy);
#     var options={chartArea:{left:0,top:0,right:0,bottom:20},
#                  legend:{position:'bottom'},curveType:'none',
#                  lineWidth:1,pointSize:3,colors:[get_color(a)],
#                  hAxis:{textColor:'#fff'},vAxis:{textColor:'#fff'}};
#     var chart=new google.visualization.LineChart(document.getElementById('div004'));
#     chart.draw(data,options); };
# </script>

# %%
dhtml('External Interactive Code Execution',c10,f2,fs7)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     External Interactive Code Execution</h1>

# %%
html_str="""<html><head><meta charset='utf-8'>"""+\
"""<meta name='viewport' content='width=device-width-3'>"""+\
"""<script src='https://sagecell.sagemath.org/static/embedded_sagecell.js'></script>"""+\
"""<script>$(function(){ sagecell.makeSagecell({"""+\
"""inputLocation:'#cell1',template:sagecell.templates.minimal,"""+\
"""evalButtonText:'run'}); });</script></head><body>"""+\
"""<style>h3 {color:#aa33ff; text-shadow:3px 3px 3px slategray;} """+\
"""pre {width:99%; padding-left:3px; border:2px double slategray;} """+\
""".sagecell_output {width:99%; border:2px double slategray; padding-right:1px;} """+\
""".sagecell_interactControlLabel:hover {padding-left:3px; color:#aa33ff; font-size:120%;} """+\
""".sagecell_interactOutput {padding-left:3px;}</style>"""+\
"""<body><h3>$$\large{\mathbb{Interactive \; 3D \; Plotting}}$$</h3>"""+\
"""<p>Click the $\large{\mathbb{run}}$ button to display an example.</p>"""+\
"""<pre><code>@interact"""+\
"""\ndef _(gnum=[3,..,6],lnum=[2,..,5]):"""+\
"""\n    LG=Graphics(); g=graphs.CubeGraph(gnum)"""+\
"""\n    vg=g.get_pos(); eg=g.edges()"""+\
"""\n    nv=len(vg); ne=len(eg); k=randint(10,50)/100"""+\
"""\n    x0=mean([list(vg.values())[i][0] for i in range(nv)])"""+\
"""\n    y0=mean([list(vg.values())[i][1] for i in range(nv)])"""+\
"""\n    coord=[[list(vg[eg[i][0]]),list(vg[eg[i][1]])] """+\
"""\n            for i in range(ne)]"""+\
"""\n    lg=[[[x-x0,y-y0] for [x,y] in coord[i]] """+\
"""\n        for i in range(ne)]"""+\
"""\n    zlg=[[[(1+k*j)*x,j,(1+k*j)*y] """+\
"""\n          for [x,y] in lg[i]] """+\
"""\n         for j in range(lnum) for i in range(ne)]"""+\
"""\n    for i in range(lnum*ne):"""+\
"""\n        LG+=line3d(zlg[i],"""+\
"""\n                   color=(floor(i/ne)/(lnum-1),"""+\
"""\n                          random(),random()))"""+\
"""\n    LG.show(frame=False,aspect_ratio=1) \n"""+\
"""</code></pre><br/>"""+\
"""<div id='cell1'><script type='text/x-sage'>"""+\
"""@interact"""+\
"""\ndef _(gnum=[3,..,6],lnum=[2,..,5]):"""+\
"""\n    LG=Graphics(); g=graphs.CubeGraph(gnum)"""+\
"""\n    vg=g.get_pos(); eg=g.edges()"""+\
"""\n    nv=len(vg); ne=len(eg); k=randint(10,50)/100"""+\
"""\n    x0=mean([list(vg.values())[i][0] for i in range(nv)])"""+\
"""\n    y0=mean([list(vg.values())[i][1] for i in range(nv)])"""+\
"""\n    coord=[[list(vg[eg[i][0]]),list(vg[eg[i][1]])] """+\
"""\n           for i in range(ne)]"""+\
"""\n    lg=[[[x-x0,y-y0] for [x,y] in coord[i]] """+\
"""\n        for i in range(ne)]"""+\
"""\n    zlg=[[[(1+k*j)*x,j,(1+k*j)*y] """+\
"""\n          for [x,y] in lg[i]] """+\
"""\n         for j in range(lnum) for i in range(ne)]"""+\
"""\n    for i in range(lnum*ne):"""+\
"""\n        LG+=line3d(zlg[i],"""+\
"""\n                   color=(floor(i/ne)/(lnum-1),"""+\
"""\n                          random(),random()))"""+\
"""\n    LG.show(frame=False,aspect_ratio=1)"""+\
"""</script></div></body></html>"""
HTML(html_str)
# Out:
# <html><head><meta charset='utf-8'><meta name='viewport' content='width=device-width-3'><script src='https://sagecell.sagemath.org/static/embedded_sagecell.js'></script><script>$(function(){ sagecell.makeSagecell({inputLocation:'#cell1',template:sagecell.templates.minimal,evalButtonText:'run'}); });</script></head><body><style>h3 {color:#aa33ff; text-shadow:3px 3px 3px slategray;} pre {width:99%; padding-left:3px; border:2px double slategray;} .sagecell_output {width:99%; border:2px double slategray; padding-right:1px;} .sagecell_interactControlLabel:hover {padding-left:3px; color:#aa33ff; font-size:120%;} .sagecell_interactOutput {padding-left:3px;}</style><body><h3>$$\large{\mathbb{Interactive \; 3D \; Plotting}}$$</h3><p>Click the $\large{\mathbb{run}}$ button to display an example.</p><pre><code>@interact
# def _(gnum=[3,..,6],lnum=[2,..,5]):
#     LG=Graphics(); g=graphs.CubeGraph(gnum)
#     vg=g.get_pos(); eg=g.edges()
#     nv=len(vg); ne=len(eg); k=randint(10,50)/100
#     x0=mean([list(vg.values())[i][0] for i in range(nv)])
#     y0=mean([list(vg.values())[i][1] for i in range(nv)])
#     coord=[[list(vg[eg[i][0]]),list(vg[eg[i][1]])]
#             for i in range(ne)]
#     lg=[[[x-x0,y-y0] for [x,y] in coord[i]]
#         for i in range(ne)]
#     zlg=[[[(1+k*j)*x,j,(1+k*j)*y]
#           for [x,y] in lg[i]]
#          for j in range(lnum) for i in range(ne)]
#     for i in range(lnum*ne):
#         LG+=line3d(zlg[i],
#                    color=(floor(i/ne)/(lnum-1),
#                           random(),random()))
#     LG.show(frame=False,aspect_ratio=1)
# </code></pre><br/><div id='cell1'><script type='text/x-sage'>@interact
# def _(gnum=[3,..,6],lnum=[2,..,5]):
#     LG=Graphics(); g=graphs.CubeGraph(gnum)
#     vg=g.get_pos(); eg=g.edges()
#     nv=len(vg); ne=len(eg); k=randint(10,50)/100
#     x0=mean([list(vg.values())[i][0] for i in range(nv)])
#     y0=mean([list(vg.values())[i][1] for i in range(nv)])
#     coord=[[list(vg[eg[i][0]]),list(vg[eg[i][1]])]
#            for i in range(ne)]
#     lg=[[[x-x0,y-y0] for [x,y] in coord[i]]
#         for i in range(ne)]
#     zlg=[[[(1+k*j)*x,j,(1+k*j)*y]
#           for [x,y] in lg[i]]
#          for j in range(lnum) for i in range(ne)]
#     for i in range(lnum*ne):
#         LG+=line3d(zlg[i],
#                    color=(floor(i/ne)/(lnum-1),
#                           random(),random()))
#     LG.show(frame=False,aspect_ratio=1)</script></div></body></html>

# %%
dhtml('External Interactive Code Cells',c10,f2,fs7)
# Out:
# <style>
#     @import 'https://fonts.googleapis.com/css?family=Akronim&effect=3d-float';</style>
#     <h1 class='font-effect-3d-float'
#     style='font-family:Akronim; color:#FF00CC; font-size:25px;'>
#     External Interactive Code Cells</h1>

# %%
# %%html
# <div id='smcell' style='border:10px double white;
#      width:520px; height:840px; overflow:auto;
#      padding:10px; background-color:ghostwhite'>
# <iframe id='if1'
# src='https://olgabelitskaya.github.io/kaggle_smc/kaggle_interactive.html'
# width='480' height='800'/></div>
# Out:
# <div id='smcell' style='border:10px double white;
#      width:520px; height:840px; overflow:auto;
#      padding:10px; background-color:ghostwhite'>
# <iframe id='if1'
# src='https://olgabelitskaya.github.io/kaggle_smc/kaggle_interactive.html'
# width='480' height='800'/></div>
