# %% [markdown]
# #### [`SageMathCell Version`](https://olgabelitskaya.github.io/sql_cookbook2.html) & [`SageMathCell Test Example`](https://olgabelitskaya.github.io/sql_test.html)
# ## 📑 Creating SQL Databases

# %%
import zipfile,sqlite3,os; import pandas as pd
import numpy as np,sympy as sp,pylab as pl
from IPython.core.display import display, HTML
from IPython.core.magic import register_line_magic
pl.rcParams['xtick.major.pad']='1'
@register_line_magic
def get_query(q):
    sp.pprint(r'SQL Queries')
    tr=[]; cursor.execute(q)
    result=cursor.fetchall()
    for r in result: 
        tr+=[r]
    display(pd.DataFrame.from_records(tr)\
              .style.set_table_styles(style_dict))
def connect_to_db(dbf):
    sqlconn=None
    try:
        sqlconn=sqlite3.connect(dbf)
        return sqlconn
    except Error as err:
        print(err)
        if sqlconn is not None:
            sqlconn.close()
connection=connect_to_db('example.db')
if connection is not None:
    cursor=connection.cursor()
thp=[('font-size','15px'),('text-align','center'),
     ('font-weight','bold'),('padding','5px 5px'),
     ('color','white'),('background-color','slategray')]
tdp=[('font-size','14px'),('padding','5px 5px'),
     ('text-align','center'),('color','darkblue'),
     ('background-color','silver')]
style_dict=[dict(selector='th',props=thp),
            dict(selector='td',props=tdp)]
fp='../input/sberbank-russian-housing-market/'
fp2='../input/meals-programs-in-seattle/'
[os.listdir(),os.listdir('../input'),
os.listdir('../input/sberbank-russian-housing-market'),
os.listdir('../input/meals-programs-in-seattle')]
# Out:
# [['example.db', '__notebook__.ipynb'],
#  ['meals-programs-in-seattle', 'sberbank-russian-housing-market'],
#  ['train.csv.zip',
#   'macro.csv.zip',
#   'data_dictionary.txt',
#   'test.csv.zip',
#   'sample_submission.csv.zip'],
#  ['socrata_metadata.json', 'meals-programs-in-seattle.csv']]

# %%
fpath='https://data.cityofnewyork.us/resource/'
se=pd.read_json(fpath+'h7rb-945c.json')
fl=['dbn','total_students',
    'graduation_rate','attendance_rate',
    'latitude','longitude',
    'city','council_district']
se=se[fl].dropna().astype({'council_district':'int'})
se.to_sql('schooledu',con=connection,if_exists='replace')
se.head(int(10)).style\
  .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dbn</th>        <th class="col_heading level0 col1" >total_students</th>        <th class="col_heading level0 col2" >graduation_rate</th>        <th class="col_heading level0 col3" >attendance_rate</th>        <th class="col_heading level0 col4" >latitude</th>        <th class="col_heading level0 col5" >longitude</th>        <th class="col_heading level0 col6" >city</th>        <th class="col_heading level0 col7" >council_district</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >08X519</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >242</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >0.49</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >0.81</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >40.8205</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col5" class="data row0 col5" >-73.8812</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col6" class="data row0 col6" >Bronx</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col7" class="data row0 col7" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >13K350</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >268</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >0.83</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >0.81</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >40.6973</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col5" class="data row1 col5" >-73.9845</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col6" class="data row1 col6" >Brooklyn</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col7" class="data row1 col7" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >28Q680</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >704</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >0.97</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >0.96</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >40.718</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col5" class="data row2 col5" >-73.8059</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col6" class="data row2 col6" >Jamaica</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col7" class="data row2 col7" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >08X282</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >305</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >0.6</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >0.79</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >40.815</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col5" class="data row3 col5" >-73.8561</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col6" class="data row3 col6" >Bronx</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col7" class="data row3 col7" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >25Q285</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >566</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >0.94</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >0.93</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >40.7649</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col5" class="data row4 col5" >-73.7894</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col6" class="data row4 col6" >Flushing</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col7" class="data row4 col7" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >13K499</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >262</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >0.7</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >0.79</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >40.6786</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col5" class="data row5 col5" >-73.9616</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col6" class="data row5 col6" >Brooklyn</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col7" class="data row5 col7" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >27Q351</td>
#                         <td id="T_603823c0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >370</td>
#                         <t

# %%
# from csv
url='https://raw.githubusercontent.com/plotly/'+\
    'datasets/master/2016-weather-data-seattle.csv'
weather=pd.read_csv(url).dropna()
weather=weather.astype({'Mean_TemperatureC':'int64',
                        'Min_TemperatureC':'int64'})
weather.to_sql('weather',con=connection,
               if_exists='replace')
weather.describe().style\
       .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Max_TemperatureC</th>        <th class="col_heading level0 col1" >Mean_TemperatureC</th>        <th class="col_heading level0 col2" >Min_TemperatureC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >24376</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >24376</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >24376</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >14.9438</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >11.0435</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >7.25103</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >7.17252</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >5.79416</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >4.91293</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >-18</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >-12</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >-17</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >7</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >14</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >11</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >20</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >16</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col0" class="data row7 col0" >54</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col1" class="data row7 col1" >31</td>
#                         <td id="T_609dd09e_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col2" class="data row7 col2" >22</td>
#             </tr>
#     </tbody></table>

# %%
# from csv
url='https://raw.githubusercontent.com/'+\
    'OlgaBelitskaya/machine_learning_engineer_nd009/'+\
    'master/Machine_Learning_Engineer_ND_P3/customers.csv'
customers=pd.read_csv(url).dropna()
customers.to_sql('customers',con=connection,
                 if_exists='replace')
customers.head(7).style\
         .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Channel</th>        <th class="col_heading level0 col1" >Region</th>        <th class="col_heading level0 col2" >Fresh</th>        <th class="col_heading level0 col3" >Milk</th>        <th class="col_heading level0 col4" >Grocery</th>        <th class="col_heading level0 col5" >Frozen</th>        <th class="col_heading level0 col6" >Detergents_Paper</th>        <th class="col_heading level0 col7" >Delicatessen</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >12669</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >9656</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >7561</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col5" class="data row0 col5" >214</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col6" class="data row0 col6" >2674</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col7" class="data row0 col7" >1338</td>
#             </tr>
#             <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >7057</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >9810</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >9568</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col5" class="data row1 col5" >1762</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col6" class="data row1 col6" >3293</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col7" class="data row1 col7" >1776</td>
#             </tr>
#             <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >6353</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >8808</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >7684</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col5" class="data row2 col5" >2405</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col6" class="data row2 col6" >3516</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col7" class="data row2 col7" >7844</td>
#             </tr>
#             <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >13265</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >1196</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >4221</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col5" class="data row3 col5" >6404</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col6" class="data row3 col6" >507</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col7" class="data row3 col7" >1788</td>
#             </tr>
#             <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >22615</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >5410</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >7198</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col5" class="data row4 col5" >3915</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col6" class="data row4 col6" >1777</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col7" class="data row4 col7" >5185</td>
#             </tr>
#             <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >2</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >9413</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >8259</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >5126</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col5" class="data row5 col5" >666</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col6" class="data row5 col6" >1795</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col7" class="data row5 col7" >1451</td>
#             </tr>
#             <tr>
#                         <th id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >2</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >3</td>
#                         <td id="T_60cabd70_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >12126</td>

# %%
# from csv
url=fp2+'meals-programs-in-seattle.csv'
meals=pd.read_csv(url).dropna()
meals.to_sql('meals',con=connection,
             if_exists='replace')
meals.tail(2).T.style\
     .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >75</th>        <th class="col_heading level0 col1" >76</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >Day_Time</th>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >Daily: 6:00 - 7:15 pm</td>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >Major Holidays Only, Thanksgiving, Christmas, New Years day.</td>
#             </tr>
#             <tr>
#                         <th id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >Meal_Served</th>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >Dinner</td>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >Dinner</td>
#             </tr>
#             <tr>
#                         <th id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >People_Served</th>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >WOMEN 18 AND OLDER</td>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >OPEN TO ALL</td>
#             </tr>
#             <tr>
#                         <th id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >Location</th>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >2030 3rd Ave, Seattle</td>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >Outdoor Meal Site at 6th and Columbia, Seattle</td>
#             </tr>
#             <tr>
#                         <th id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >Name_of_Program</th>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >Women's Referral Center</td>
#                         <td id="T_60d4e4d0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >Friends of Francois</td>
#             </tr>
#     </tbody></table>

# %%
# from csv
url=fp+'macro.csv.zip'
macro=pd.read_csv(url)
fl=['timestamp','oil_urals','brent','cpi','ppi',
    'usdrub','eurrub','salary','salary_growth',
    'unemployment','employment','average_life_exp',
    'pop_natural_increase','childbirth']
macro=macro[fl].dropna()
macro.to_sql('macro',con=connection,
             if_exists='replace')
macro.tail(int(7)).T.style\
     .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2184</th>        <th class="col_heading level0 col1" >2185</th>        <th class="col_heading level0 col2" >2186</th>        <th class="col_heading level0 col3" >2187</th>        <th class="col_heading level0 col4" >2188</th>        <th class="col_heading level0 col5" >2189</th>        <th class="col_heading level0 col6" >2190</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >timestamp</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >2015-12-25</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >2015-12-26</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >2015-12-27</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >2015-12-28</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >2015-12-29</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col5" class="data row0 col5" >2015-12-30</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col6" class="data row0 col6" >2015-12-31</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >oil_urals</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >36.7805</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >36.7805</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >36.7805</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >36.7805</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >36.7805</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col5" class="data row1 col5" >36.7805</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col6" class="data row1 col6" >36.7805</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >brent</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >37.89</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >37.89</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >37.89</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >36.62</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >37.79</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col5" class="data row2 col5" >36.46</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col6" class="data row2 col6" >37.28</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >cpi</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >506.4</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >506.4</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >506.4</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >506.4</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >506.4</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col5" class="data row3 col5" >506.4</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col6" class="data row3 col6" >506.4</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >ppi</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >581.6</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >581.6</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >581.6</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >581.6</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >581.6</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col5" class="data row4 col5" >581.6</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col6" class="data row4 col6" >581.6</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >usdrub</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >70.6396</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >70.6396</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >70.6396</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >72.0838</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >72.2141</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col5" class="data row5 col5" >73.4343</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col6" class="data row5 col6" >72.851</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >eurrub</th>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >77.1132</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >77.1132</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >77.1132</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col3" class="data row6 col3" >79.1101</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col4" class="data row6 col4" >78.9353</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col5" class="data row6 col5" >80.1153</td>
#                         <td id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col6" class="data row6 col6" >79.3106</td>
#             </tr>
#             <tr>
#                         <th id="T_60eb4540_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading l

# %%
# from csv
zipf=zipfile.ZipFile(fp+'train.csv.zip','r')
zipf.extractall(''); zipf.close()
housing=pd.read_csv('train.csv')
fnum=['timestamp','full_sq','floor','max_floor','num_room',
      'area_m','kremlin_km','big_road2_km','big_road1_km',
      'workplaces_km','stadium_km','swim_pool_km','fitness_km',
      'detention_facility_km','cemetery_km','radiation_km',
      'oil_chemistry_km','theater_km','exhibition_km','museum_km',
      'park_km','public_healthcare_km','metro_min_walk',
      'metro_km_avto', 'bus_terminal_avto_km',
      'public_transport_station_min_walk',
      'railroad_station_walk_min','railroad_station_avto_km',
      'kindergarten_km','school_km','preschool_km',
      'university_km','additional_education_km',
      'shopping_centers_km','big_market_km','ekder_all',
      'work_all','young_all']
fcat=['sub_area','ID_metro','office_raion',
      'raion_popul','healthcare_centers_raion',
      'school_education_centers_raion','sport_objects_raion',
      'preschool_education_centers_raion']
housing=housing[fnum+fcat].dropna()
housing.to_sql('housing',con=connection,
               if_exists='replace')
housing.tail(int(5)).T.style\
       .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >30466</th>        <th class="col_heading level0 col1" >30467</th>        <th class="col_heading level0 col2" >30468</th>        <th class="col_heading level0 col3" >30469</th>        <th class="col_heading level0 col4" >30470</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >timestamp</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >2015-06-30</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >2015-06-30</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >2015-06-30</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >2015-06-30</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >2015-06-30</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >full_sq</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >44</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >86</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >45</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >64</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >floor</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >7</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >10</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >5</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >max_floor</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >9</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >20</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >15</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >num_room</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >4</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >1</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >2</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >area_m</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >1.00531e+07</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >7.30741e+06</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >2.55363e+07</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >6.05006e+06</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >4.39533e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >kremlin_km</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >12.5993</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >3.26928</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >21.9058</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col3" class="data row6 col3" >13.6226</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col4" class="data row6 col4" >11.8126</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading level0 row7" >big_road2_km</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col0" class="data row7 col0" >3.76241</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col1" class="data row7 col1" >1.2457</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col2" class="data row7 col2" >3.68841</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col3" class="data row7 col3" >2.174</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col4" class="data row7 col4" >2.08923</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row8" class="row_heading level0 row8" >big_road1_km</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col0" class="data row8 col0" >3.09606</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col1" class="data row8 col1" >1.23873</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col2" class="data row8 col2" >2.80808</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col3" class="data row8 col3" >0.960608</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col4" class="data row8 col4" >1.92088</td>
#             </tr>
#             <tr>
#                         <th id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row9" class="row_heading level0 row9" >workplaces_km</th>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row9_col0" class="data row9 col0" >1.44258</td>
#                         <td id="T_628eb3a0_73fb_11ea_8ccb_5ba0f4c0cdc6row9_col1" class="data row9 col1" >0.796851</td>

# %%
# from csv
url='https://raw.githubusercontent.com/noahgift/'+\
    'mma/master/data/ufc_fights_all.csv'
mma=pd.read_csv(url).dropna()
mma.to_sql('mma',con=connection,
           if_exists='replace')
mma.tail(int(2)).T.style\
   .set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >3567</th>        <th class="col_heading level0 col1" >3568</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >pageurl</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >/events/UFC-Fight-Night-83-Cerrone-vs-Oliveira-47935</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >/events/UFC-Fight-Night-83-Cerrone-vs-Oliveira-47935</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >eid</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >47935</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >47935</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >mid</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >event_name</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >UFC Fight Night 83 - Cerrone vs. Oliveira</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >UFC Fight Night 83 - Cerrone vs. Oliveira</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >event_org</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >Ultimate Fighting Championship</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >Ultimate Fighting Championship</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >event_date</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >2/21/16</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >2/21/16</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >event_place</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >Consol Energy Center, Pittsburgh, Pennsylvania, United States</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >Consol Energy Center, Pittsburgh, Pennsylvania, United States</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading level0 row7" >f1pageurl</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col0" class="data row7 col0" >/fighter/Lauren-Murphy-66725</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col1" class="data row7 col1" >/fighter/Shamil-Abdurakhimov-26808</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row8" class="row_heading level0 row8" >f2pageurl</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col0" class="data row8 col0" >/fighter/Kelly-Faszholz-117453</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col1" class="data row8 col1" >/fighter/Anthony-Hamilton-58947</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row9" class="row_heading level0 row9" >f1name</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row9_col0" class="data row9 col0" >Lauren Murphy</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row9_col1" class="data row9 col1" >Shamil Abdurakhimov</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row10" class="row_heading level0 row10" >f2name</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row10_col0" class="data row10 col0" >Kelly Faszholz</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row10_col1" class="data row10 col1" >Anthony Hamilton</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row11" class="row_heading level0 row11" >f1result</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row11_col0" class="data row11 col0" >win</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row11_col1" class="data row11 col1" >win</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row12" class="row_heading level0 row12" >f2result</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row12_col0" class="data row12 col0" >loss</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row12_col1" class="data row12 col1" >loss</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row13" class="row_heading level0 row13" >f1fid</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row13_col0" class="data row13 col0" >66725</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row13_col1" class="data row13 col1" >26808</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row14" class="row_heading level0 row14" >f2fid</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row14_col0" class="data row14 col0" >117453</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row14_col1" class="data row14 col1" >58947</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row15" class="row_heading level0 row15" >method</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row15_col0" class="data row15 col0" >TKO</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row15_col1" class="data row15 col1" >Decision</td>
#             </tr>
#             <tr>
#                         <th id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row16" class="row_heading level0 row16" >method_d</th>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row16_col0" class="data row16 col0" >Elbows and Punches</td>
#                         <td id="T_62da8ece_73fb_11ea_8ccb_5ba0f4c0cdc6row16_col1" class="data row16 col1" >Unanimous</td>
#             </tr>
#             <tr>

# %% [markdown]
# ## 📑 The Database Structure

# %%
# %get_query \
SELECT * \
FROM sqlite_master;
# Out:
# SQL Queries
# <style  type="text/css" >
#     #T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >table</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >schooledu</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >schooledu</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >2</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >CREATE TABLE "schooledu" (
# "index" INTEGER,
#   "dbn" TEXT,
#   "total_students" INTEGER,
#   "graduation_rate" TEXT,
#   "attendance_rate" REAL,
#   "latitude" REAL,
#   "longitude" REAL,
#   "city" TEXT,
#   "council_district" INTEGER
# )</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >ix_schooledu_index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >schooledu</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >3</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >CREATE INDEX "ix_schooledu_index"ON "schooledu" ("index")</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >table</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >weather</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >weather</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >11</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >CREATE TABLE "weather" (
# "index" INTEGER,
#   "Date" TEXT,
#   "Max_TemperatureC" INTEGER,
#   "Mean_TemperatureC" INTEGER,
#   "Min_TemperatureC" INTEGER
# )</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >ix_weather_index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >weather</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >12</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >CREATE INDEX "ix_weather_index"ON "weather" ("index")</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >table</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >customers</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >customers</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >232</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >CREATE TABLE "customers" (
# "index" INTEGER,
#   "Channel" INTEGER,
#   "Region" INTEGER,
#   "Fresh" INTEGER,
#   "Milk" INTEGER,
#   "Grocery" INTEGER,
#   "Frozen" INTEGER,
#   "Detergents_Paper" INTEGER,
#   "Delicatessen" INTEGER
# )</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >ix_customers_index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >customers</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >233</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >CREATE INDEX "ix_customers_index"ON "customers" ("index")</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >table</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >meals</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >meals</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col3" class="data row6 col3" >240</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col4" class="data row6 col4" >CREATE TABLE "meals" (
# "index" INTEGER,
#   "Day_Time" TEXT,
#   "Meal_Served" TEXT,
#   "People_Served" TEXT,
#   "Location" TEXT,
#   "Name_of_Program" TEXT
# )</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col0" class="data row7 col0" >index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col1" class="data row7 col1" >ix_meals_index</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col2" class="data row7 col2" >meals</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col3" class="data row7 col3" >241</td>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col4" class="data row7 col4" >CREATE INDEX "ix_meals_index"ON "meals" ("index")</td>
#             </tr>
#             <tr>
#                         <th id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_62dda118_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col0" class="data row8 col0" >table</td>

# %%
# %get_query \
PRAGMA table_info("macro")
# Out:
# SQL Queries
# <style  type="text/css" >
#     #T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >index</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >INTEGER</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col5" class="data row0 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >timestamp</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >TEXT</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col5" class="data row1 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >oil_urals</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >REAL</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col5" class="data row2 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >brent</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >REAL</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col5" class="data row3 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >cpi</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >REAL</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col5" class="data row4 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >ppi</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >REAL</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col5" class="data row5 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >usdrub</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >REAL</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col4" class="data row6 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col5" class="data row6 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col1" class="data row7 col1" >eurrub</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col2" class="data row7 col2" >REAL</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col3" class="data row7 col3" >0</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col4" class="data row7 col4" >None</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col5" class="data row7 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_62e158c6_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col1" class="data row8 col1" >salary

# %% [markdown]
# ## 📑 SQL Basic Queries

# %%
# %get_query \
SELECT CURRENT_TIMESTAMP;
# Out:
# SQL Queries
# <style  type="text/css" >
#     #T_62e4cd94_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62e4cd94_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62e4cd94_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62e4cd94_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62e4cd94_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >2020-04-01 09:30:12</td>
#             </tr>
#     </tbody></table>

# %%
# %get_query \
SELECT DISTINCT * \
FROM (VALUES ('x'),('y'),('z'),\
             ('X'),('Y'),('Z'),\
             ('x'),('y'),('z'))
# Out:
# SQL Queries
# <style  type="text/css" >
#     #T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >x</td>
#             </tr>
#             <tr>
#                         <th id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >y</td>
#             </tr>
#             <tr>
#                         <th id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >z</td>
#             </tr>
#             <tr>
#                         <th id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >X</td>
#             </tr>
#             <tr>
#                         <th id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >Y</td>
#             </tr>
#             <tr>
#                         <th id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_62e76b80_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >Z</td>
#             </tr>
#     </tbody></table>

# %%
# %get_query \
SELECT DISTINCT Name_of_Program As programs \
FROM meals \
WHERE People_Served="OPEN TO ALL";
# Out:
# SQL Queries
# <style  type="text/css" >
#     #T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >South Park Breakfast Bunch</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >Union Gospel Mission</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >Sacred Heart Church/SVDP Society</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >Operation Sack Lunch</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >Our Lady of Mt. Carmel</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >Mother's Kitchen</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >Magic Works Alumni</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row7_col0" class="data row7 col0" >ACRS Food Bank</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row8_col0" class="data row8 col0" >Set Free Ministries</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row9_col0" class="data row9 col0" >Emergency Senior Nutrition Program</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row10_col0" class="data row10 col0" >Saint Luke's Episcopal Church</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row11_col0" class="data row11 col0" >Latino Lunch</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row12_col0" class="data row12 col0" >PAEP/Polynesian Nutrition Program</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row13_col0" class="data row13 col0" >Hopelink/Sno-Valley</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row14_col0" class="data row14 col0" >Bible Study Out Reach Ministries</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row15_col0" class="data row15 col0" >Blessed Sacrament Church Sunday Dinner </td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row16_col0" class="data row16 col0" >Bread of Life Mission</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row17_col0" class="data row17 col0" >Community Lunch on Capitol Hill</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row18_col0" class="data row18 col0" >El Centro de La Raza</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row19_col0" class="data row19 col0" >Community Lunch / Immanuel Community Services</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row20_col0" class="data row20 col0" >Phinney Neighborhood Association</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row21_col0" class="data row21 col0" >Anonomous Acts of Kindness</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row22_col0" class="data row22 col0" >Monday Feeding Program</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6row23_col0" class="data row23 col0" >PAEP/Filipino Senior Services</td>
#             </tr>
#             <tr>
#                         <th id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row24" class="row_heading level0 row24" >24</th>
#                         <td id="T_62e9f512_73fb_11ea_8ccb_5ba0f4c0c

# %%
pd.read_sql_query('''
SELECT "📑 "||dbn||" 🏙 "||city AS dbn_city,graduation_rate
FROM schooledu
WHERE city="Bronx" AND dbn LIKE "10%" AND
graduation_rate>.9 AND graduation_rate<>"N/A";
''',con=connection)\
.style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dbn_city</th>        <th class="col_heading level0 col1" >graduation_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >📑 10X442 🏙 Bronx</td>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >0.91</td>
#             </tr>
#             <tr>
#                         <th id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >📑 10X437 🏙 Bronx</td>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >0.97</td>
#             </tr>
#             <tr>
#                         <th id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >📑 10X696 🏙 Bronx</td>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >📑 10X374 🏙 Bronx</td>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >0.91</td>
#             </tr>
#             <tr>
#                         <th id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >📑 10X477 🏙 Bronx</td>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >0.93</td>
#             </tr>
#             <tr>
#                         <th id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >📑 10X445 🏙 Bronx</td>
#                         <td id="T_62ed3ac4_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >1</td>
#             </tr>
#     </tbody></table>

# %%
pd.read_sql_query('''
SELECT " 🏙 "||city||" 📑 "||dbn AS dbn_city,
       graduation_rate+attendance_rate 
       AS graduation_attendance_rate
FROM schooledu
WHERE graduation_attendance_rate<1.3 AND 
graduation_rate<>"N/A" AND attendance_rate<>"N/A";
''',con=connection)\
.style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dbn_city</th>        <th class="col_heading level0 col1" >graduation_attendance_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" > 🏙 Manhattan 📑 05M367</td>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >1.16</td>
#             </tr>
#             <tr>
#                         <th id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" > 🏙 Jamaica 📑 27Q400</td>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >1.21</td>
#             </tr>
#             <tr>
#                         <th id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" > 🏙 Bronx 📑 08X530</td>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >1.21</td>
#             </tr>
#             <tr>
#                         <th id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" > 🏙 Bronx 📑 12X479</td>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >1.18</td>
#             </tr>
#             <tr>
#                         <th id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" > 🏙 Manhattan 📑 04M409</td>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >1.29</td>
#             </tr>
#             <tr>
#                         <th id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" > 🏙 Bronx 📑 10X524</td>
#                         <td id="T_62efb0b0_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >1.26</td>
#             </tr>
#     </tbody></table>

# %%
q=pd.read_sql_query('''
SELECT salary,average_life_exp,
       employment,unemployment
FROM macro;
''',con=connection)
q.plot(kind='kde',figsize=(6,12),
       cmap=pl.cm.winter,
       subplots=True,sharex=False)
pl.show()

# %%
q=pd.read_sql_query('''
SELECT usdrub,eurrub,oil_urals,brent
FROM macro;
''',con=connection)
fl=['usdrub','eurrub','oil_urals','brent']
qp=q.plot(kind='line',figsize=(10,6),
       secondary_y=fl[2:],cmap=pl.cm.winter)
lines=qp.get_lines()+qp.right_ax.get_lines()
qp.legend(lines,[l.get_label() for l in lines],
          bbox_to_anchor=(.2,.6))
pl.grid(); pl.show()

# %% [markdown]
# ## 📑 SQL & Pandas Comparing

# %%
display(weather\
        .groupby(weather['Date']\
                 .map(lambda x: x[-4:]))\
        .mean().tail().style\
        .set_table_styles(style_dict))
q=pd.read_sql_query('''
SELECT SUBSTR(Date,-4,4) AS Years,
       AVG(Max_TemperatureC),
       AVG(Mean_TemperatureC),
       AVG(Min_TemperatureC)
FROM weather
GROUP BY Years;
''',con=connection).set_index('Years')
q.plot(kind='area',figsize=(6,4),
       alpha=.7,cmap=pl.cm.tab10)
pl.show()
q.tail().style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Max_TemperatureC</th>        <th class="col_heading level0 col1" >Mean_TemperatureC</th>        <th class="col_heading level0 col2" >Min_TemperatureC</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >2010</th>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >15.3671</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >11.6493</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >7.67671</td>
#             </tr>
#             <tr>
#                         <th id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >2012</th>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >15.2541</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >11.4098</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >7.28142</td>
#             </tr>
#             <tr>
#                         <th id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2013</th>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >16.0822</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >12.2521</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >8.10685</td>
#             </tr>
#             <tr>
#                         <th id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >2014</th>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >16.9808</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >12.9836</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >8.67123</td>
#             </tr>
#             <tr>
#                         <th id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >2015</th>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >17.4301</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >13.2575</td>
#                         <td id="T_648cc70a_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >8.82192</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AVG(Max_TemperatureC)</th>        <th class="col_heading level0 col1" >AVG(Mean_TemperatureC)</th>        <th class="col_heading level0 col2" >AVG(Min_TemperatureC)</th>    </tr>    <tr>        <th class="index_name level0" >Years</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >2010</th>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >15.3671</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >11.6493</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >7.67671</td>
#             </tr>
#             <tr>
#                         <th id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >2012</th>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >15.2541</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >11.4098</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >7.28142</td>
#             </tr>
#             <tr>
#                         <th id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2013</th>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >16.0822</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >12.2521</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >8.10685</td>
#             </tr>
#             <tr>
#                         <th id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >2014</th>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >16.9808</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >12.9836</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >8.67123</td>
#             </tr>
#             <tr>
#                         <th id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >2015</th>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >17.4301</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >13.2575</td>
#                         <td id="T_64c6883c_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >8.82192</td>
#             </tr>
#     </tbody></table>

# %%
fl=['Fresh','Milk','Grocery','Frozen',
    'Detergents_Paper','Delicatessen']
display(customers[fl].where(customers.Fresh>50000)\
        .dropna().sort_values('Fresh',ascending=False)\
        .astype('int64').style.set_table_styles(style_dict))
q=pd.read_sql_query('''
SELECT Fresh,Milk,Grocery,Frozen,
       Detergents_Paper,Delicatessen
FROM customers
WHERE Fresh>50000
ORDER BY Fresh DESC;
''',con=connection)
q.plot(kind='area',cmap=pl.cm.tab10,
       alpha=.7,figsize=(6,4))
pl.show()
q.style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fresh</th>        <th class="col_heading level0 col1" >Milk</th>        <th class="col_heading level0 col2" >Grocery</th>        <th class="col_heading level0 col3" >Frozen</th>        <th class="col_heading level0 col4" >Detergents_Paper</th>        <th class="col_heading level0 col5" >Delicatessen</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >181</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >112151</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >29627</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >18148</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >16745</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >4948</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col5" class="data row0 col5" >8550</td>
#             </tr>
#             <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >125</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >76237</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >3473</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >7102</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >16538</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >778</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col5" class="data row1 col5" >918</td>
#             </tr>
#             <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >284</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >68951</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >4411</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >12609</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >8692</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >751</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col5" class="data row2 col5" >2406</td>
#             </tr>
#             <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >39</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >56159</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >555</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >902</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >10002</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >212</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col5" class="data row3 col5" >2916</td>
#             </tr>
#             <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >258</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >56083</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >4563</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >2124</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >6422</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >730</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col5" class="data row4 col5" >3321</td>
#             </tr>
#             <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >103</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >56082</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >3504</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >8906</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >18028</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >1480</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col5" class="data row5 col5" >2498</td>
#             </tr>
#             <tr>
#                         <th id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >259</th>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >53205</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >4959</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >7336</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col3" class="data row6 col3" >3012</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col4" class="data row6 col4" >967</td>
#                         <td id="T_64cb6da2_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col5" class="data row6 col5" >818</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Fresh</th>        <th class="col_heading level0 col1" >Milk</th>        <th class="col_heading level0 col2" >Grocery</th>        <th class="col_heading level0 col3" >Frozen</th>        <th class="col_heading level0 col4" >Detergents_Paper</th>        <th class="col_heading level0 col5" >Delicatessen</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >112151</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >29627</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >18148</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col3" class="data row0 col3" >16745</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col4" class="data row0 col4" >4948</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col5" class="data row0 col5" >8550</td>
#             </tr>
#             <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >76237</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >3473</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >7102</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col3" class="data row1 col3" >16538</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col4" class="data row1 col4" >778</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col5" class="data row1 col5" >918</td>
#             </tr>
#             <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >68951</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >4411</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >12609</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col3" class="data row2 col3" >8692</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col4" class="data row2 col4" >751</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col5" class="data row2 col5" >2406</td>
#             </tr>
#             <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >56159</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >555</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >902</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col3" class="data row3 col3" >10002</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col4" class="data row3 col4" >212</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col5" class="data row3 col5" >2916</td>
#             </tr>
#             <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >56083</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >4563</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >2124</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col3" class="data row4 col3" >6422</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col4" class="data row4 col4" >730</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col5" class="data row4 col5" >3321</td>
#             </tr>
#             <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >56082</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >3504</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >8906</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col3" class="data row5 col3" >18028</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col4" class="data row5 col4" >1480</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col5" class="data row5 col5" >2498</td>
#             </tr>
#             <tr>
#                         <th id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >53205</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >4959</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >7336</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col3" class="data row6 col3" >3012</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col4" class="data row6 col4" >967</td>
#                         <td id="T_64f71cea_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col5" class="data row6 col5" >818</td>
#             </tr>
#     </tbody></table>

# %%
fl=['workplaces_km','public_transport_station_min_walk',
    'school_km','public_healthcare_km']
display(housing[fl]\
        .groupby(housing['ID_metro'])\
        .mean().tail(3).T.style\
        .set_table_styles(style_dict))
q=pd.read_sql_query('''
SELECT ID_metro,
       AVG(workplaces_km),
       AVG(public_transport_station_min_walk),
       AVG(school_km),
       AVG(public_healthcare_km)
FROM housing
GROUP BY ID_metro;
''',con=connection).set_index('ID_metro')
q.iloc[:,int(1):].plot(kind='area',figsize=(10,5),
       alpha=.7,cmap=pl.cm.tab10)
pl.show()
q.tail(3).T.style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="index_name level0" >ID_metro</th>        <th class="col_heading level0 col0" >221</th>        <th class="col_heading level0 col1" >222</th>        <th class="col_heading level0 col2" >223</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >workplaces_km</th>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >0.287218</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >2.33879</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >1.66627</td>
#             </tr>
#             <tr>
#                         <th id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >public_transport_station_min_walk</th>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >3.95788</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >0.522029</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >1.18906</td>
#             </tr>
#             <tr>
#                         <th id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >school_km</th>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >0.273374</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >0.243305</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >0.32668</td>
#             </tr>
#             <tr>
#                         <th id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >public_healthcare_km</th>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >1.36559</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >3.18113</td>
#                         <td id="T_64fbdc94_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >1.04844</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
#     #T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="index_name level0" >ID_metro</th>        <th class="col_heading level0 col0" >221</th>        <th class="col_heading level0 col1" >222</th>        <th class="col_heading level0 col2" >223</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >AVG(workplaces_km)</th>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >0.287218</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >2.33879</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >1.66627</td>
#             </tr>
#             <tr>
#                         <th id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >AVG(public_transport_station_min_walk)</th>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >3.95788</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >0.522029</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >1.18906</td>
#             </tr>
#             <tr>
#                         <th id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >AVG(school_km)</th>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >0.273374</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >0.243305</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >0.32668</td>
#             </tr>
#             <tr>
#                         <th id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >AVG(public_healthcare_km)</th>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >1.36559</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >3.18113</td>
#                         <td id="T_65327ae2_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >1.04844</td>
#             </tr>
#     </tbody></table>

# %%
q=pd.read_sql_query('''
SELECT method,
       COUNT(*) AS number,
       AVG(round) AS avg_round
FROM mma
GROUP BY method;
''',con=connection).set_index('method')
q.plot(secondary_y='avg_round',
       figsize=(10,5),cmap=pl.cm.winter)
pl.show()
q.tail().style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number</th>        <th class="col_heading level0 col1" >avg_round</th>    </tr>    <tr>        <th class="index_name level0" >method</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >NC</th>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >26</td>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >No</th>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >6</td>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >2.33333</td>
#             </tr>
#             <tr>
#                         <th id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >Submission</th>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >685</td>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >1.61606</td>
#             </tr>
#             <tr>
#                         <th id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >TKO</th>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >687</td>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >1.65502</td>
#             </tr>
#             <tr>
#                         <th id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >Technical</th>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >64</td>
#                         <td id="T_6576fc1c_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >1.67188</td>
#             </tr>
#     </tbody></table>

# %%
q=pd.read_sql_query('''
SELECT method_d,
       COUNT(*) AS number,
       AVG(time) AS avg_time
FROM mma
GROUP BY method_d;
''',con=connection)
n,m=int(70),int(7)
pl.rcParams['xtick.major.pad']='-10'
pl.rcParams['xtick.bottom']=\
pl.rcParams['xtick.labelbottom']=False
pl.rcParams['xtick.top']=\
pl.rcParams['xtick.labeltop']=True
qp=q.tail(n).plot(secondary_y='avg_time',
                  figsize=(10,6),alpha=.5,
                  lw=3,cmap=pl.cm.winter)
qp.set_xticks(q.tail(n).index)
qp.set_xticklabels(q.method_d[:n],va='top',
                   fontsize=7,rotation=90)
lines=qp.get_lines()+qp.right_ax.get_lines()
qp.legend(lines,[l.get_label() for l in lines],
          bbox_to_anchor=(.9,.5))
pl.show()
q.tail(m).style.set_table_styles(style_dict)
# Out:
# <style  type="text/css" >
#     #T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6 th {
#           font-size: 15px;
#           text-align: center;
#           font-weight: bold;
#           padding: 5px 5px;
#           color: white;
#           background-color: slategray;
#     }    #T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6 td {
#           font-size: 14px;
#           padding: 5px 5px;
#           text-align: center;
#           color: darkblue;
#           background-color: silver;
#     }</style><table id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >method_d</th>        <th class="col_heading level0 col1" >number</th>        <th class="col_heading level0 col2" >avg_time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row0" class="row_heading level0 row0" >155</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col0" class="data row0 col0" >Toe Hold</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row0_col2" class="data row0 col2" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row1" class="row_heading level0 row1" >156</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col0" class="data row1 col0" >Triangle Armbar</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col1" class="data row1 col1" >8</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row1_col2" class="data row1 col2" >2.375</td>
#             </tr>
#             <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row2" class="row_heading level0 row2" >157</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col0" class="data row2 col0" >Triangle Choke</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col1" class="data row2 col1" >39</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row2_col2" class="data row2 col2" >2.82051</td>
#             </tr>
#             <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row3" class="row_heading level0 row3" >158</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col0" class="data row3 col0" >Triangle Kimura</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row3_col2" class="data row3 col2" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row4" class="row_heading level0 row4" >159</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col0" class="data row4 col0" >Twister</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col1" class="data row4 col1" >1</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row4_col2" class="data row4 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row5" class="row_heading level0 row5" >160</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col0" class="data row5 col0" >Unanimous</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col1" class="data row5 col1" >1060</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row5_col2" class="data row5 col2" >5.12642</td>
#             </tr>
#             <tr>
#                         <th id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6level0_row6" class="row_heading level0 row6" >161</th>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col0" class="data row6 col0" >Wheel Kick and Punches</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col1" class="data row6 col1" >1</td>
#                         <td id="T_67a57c7a_73fb_11ea_8ccb_5ba0f4c0cdc6row6_col2" class="data row6 col2" >4</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 📑 Close the Connection and Delete This Database

# %%
if connection is not None:
    connection.close()
if os.path.exists('example.db'):
    os.remove('example.db')
else:
    print('The file does not exist')
os.remove('train.csv')
os.listdir()
# Out:
# ['__MACOSX', '__notebook__.ipynb']
