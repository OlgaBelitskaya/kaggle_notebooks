# %% [markdown]
# # &#x1F4D1; &nbsp;  Build  a  Digit Recognition Models

# %% [markdown]
# ## Links
# Multi-dimensional image processing https://docs.scipy.org/doc/scipy/reference/ndimage.html
#
# Keras: Deep Learning library for Theano and TensorFlow https://keras.io/
#
# Deep MNIST for Experts https://www.tensorflow.org/get_started/mnist/pros
#
# Tensorflow Deep MNIST Advanced Tutorial http://docs.seldon.io/tensorflow-deep-mnist-example.html
#
# Handwritten Digit Recognition using Convolutional Neural Networks in Python with Keras
#
# http://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import scipy as sp
import pandas as pd
from time import time

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pylab as plt
import matplotlib.cm as cm

# %matplotlib inline

# %%
from sklearn.neural_network import MLPClassifier, BernoulliRBM
from sklearn import linear_model, datasets, metrics
from sklearn.pipeline import Pipeline
from sklearn import manifold, decomposition, ensemble
from sklearn import discriminant_analysis, random_projection
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf

import keras as ks
from keras.models import Sequential, load_model, Model
from keras.preprocessing import sequence
from keras.optimizers import SGD, RMSprop
from keras.layers import Dense, Dropout, LSTM
from keras.layers import Activation, Flatten, Input, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D
from keras.layers.embeddings import Embedding

# %% [markdown]
# ## Dataset

# %%
df_train = pd.read_csv("kaggle_train.csv")
df_test = pd.read_csv("kaggle_test.csv")

# %%
df_train.shape
# Out:
# (42000, 785)

# %%
df_train.ix[15:20,15:20]
# Out:
#     pixel14  pixel15  pixel16  pixel17  pixel18
# 15        0        0        0        0        0
# 16        0        0        0        0        0
# 17        0        0        0        0        0
# 18        0        0        0        0        0
# 19        0        0        0        0        0
# 20        0        0        0        0        0

# %%
images = ["%s%s" %("pixel",pixel_no) for pixel_no in range(0,784)]
train_images = np.array(df_train[images])
train_images.shape
# Out:
# (42000, 784)

# %%
train_labels = df_train['label']
train_labels10 = np.array(ks.utils.to_categorical(train_labels, num_classes=10))
train_labels10.shape
# Out:
# (42000, 10)

# %%
test_images = np.array(df_test[images])
test_images.shape
# Out:
# (28000, 784)

# %%
train_images28 = np.array([np.reshape(x, (28, 28)) for x in train_images])
test_images28 = np.array([np.reshape(x, (28, 28)) for x in test_images])
train_images28n = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
test_images28n = test_images.reshape(test_images.shape[0], 28, 28, 1).astype('float32')

# %%
X_train, X_test, y_train, y_test = train_test_split(train_images28n, train_labels10, 
                                                 test_size=0.20, random_state=32)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(train_images, train_labels10, 
                                                 test_size=0.20, random_state=32)

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(train_images, train_labels, 
                                                 test_size=0.20, random_state=32)

# %% [markdown]
# ## Examples

# %%
fig, ax = plt.subplots(figsize=(18, 2), nrows=1, ncols=15, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(15):
    image = train_images28[i]
    ax[i].imshow(image, cmap=plt.cm.Blues)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[7].set_title('Examples of the 784-dimensional digits', fontsize=25);

# %% [markdown]
# ## Models

# %% [markdown]
# ***Model #1. Convolutional Neural Network. Keras***

# %%
def cnn_model11():
    model_input = Input(shape=(28, 28, 1))
    x = BatchNormalization()(model_input)
    
    x = Conv2D(28, (5, 5), activation='relu', border_mode='same')(x)
#    x = Conv2D(28, (5, 5), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    
    x = Conv2D(56, (5, 5), activation='relu')(x)
#    x = Conv2D(56, (5, 5), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    
    x = Flatten()(x)
    
    x = Dense(224, activation='relu')(x)
    x = Dropout(0.5)(x)
    
    y = Dense(10, activation='softmax')(x)
    
    model = Model(input=model_input, output=y)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn_model11 = cnn_model11()

fit11 = cnn_model11.fit(X_train, y_train, validation_data=(X_test, y_test), 
                        epochs=15, batch_size=28, verbose=2)
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/15
# 95s - loss: 0.2382 - acc: 0.9246 - val_loss: 0.0635 - val_acc: 0.9793
# Epoch 2/15
# 101s - loss: 0.0869 - acc: 0.9737 - val_loss: 0.0483 - val_acc: 0.9850
# Epoch 3/15
# 97s - loss: 0.0702 - acc: 0.9790 - val_loss: 0.0455 - val_acc: 0.9864
# Epoch 4/15
# 93s - loss: 0.0581 - acc: 0.9820 - val_loss: 0.0371 - val_acc: 0.9888
# Epoch 5/15
# 79s - loss: 0.0484 - acc: 0.9847 - val_loss: 0.0327 - val_acc: 0.9910
# Epoch 6/15
# 82s - loss: 0.0472 - acc: 0.9860 - val_loss: 0.0321 - val_acc: 0.9900
# Epoch 7/15
# 79s - loss: 0.0419 - acc: 0.9867 - val_loss: 0.0313 - val_acc: 0.9914
# Epoch 8/15
# 81s - loss: 0.0347 - acc: 0.9887 - val_loss: 0.0296 - val_acc: 0.9923
# Epoch 9/15
# 79s - loss: 0.0315 - acc: 0.9894 - val_loss: 0.0308 - val_acc: 0.9923
# Epoch 10/15
# 3291s - loss: 0.0297 - acc: 0.9907 - val_loss: 0.0287 - val_acc: 0.9917
# Epoch 11/15
# 100s - loss: 0.0285 - acc: 0.9910 - val_loss: 0.0324 - val_acc: 0.9926
# Epoch 12/15
# 91s - loss: 0.0264 - acc: 0.9913 - val_loss: 0.0294 - val_acc: 0.9924
# Epoch 13/15
# 86s - loss: 0.0254 - acc: 0.9918 - val_loss: 0.0257 - val_acc: 0.9919
# Epoch 14/15
# 86s - loss: 0.0233 - acc: 0.9930 - val_loss: 0.0295 - val_acc: 0.9931
# Epoch 15/15
# 85s - loss: 0.0230 - acc: 0.9933 - val_loss: 0.0293 - val_acc: 0.9925

# %%
plt.figure(figsize=(18,5))
plt.plot(fit11.history['acc'], '-o', label = 'train')
plt.plot(fit11.history['val_acc'], '-o', label = 'test')
plt.legend()
plt.title('Accuracy');

# %%
cnn_scores1 = cnn_model11.evaluate(X_test, y_test, verbose=0)

print("Model 1. CNN Scores: " , (cnn_scores1))
print("Model 1. CNN Error: %.2f%%" % (100 - cnn_scores1[1]*100))
print(cnn_model11.summary())
# Out:
# Model 1. CNN Scores:  [0.040152256446625532, 0.99321428571428572]
# Model 1. CNN Error: 0.68%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 28, 28, 1)         0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 28, 28, 1)         4
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 28, 28, 28)        728
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 14, 14, 28)        0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 14, 14, 28)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 10, 10, 56)        39256
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 5, 5, 56)          0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 5, 5, 56)          0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1400)              0
# _________________________________________________________________
# dense_25 (Dense)             (None, 448)               627648
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 448)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                4490
# =================================================================
# Total params: 672,126
# Trainable params: 672,124
# Non-trainable params: 2
# _________________________________________________________________
# None

# %%
# cnn_model11.save('cnn_model11_file1.h5')
# cnn_model11.save('cnn_model11_file2.h5')
cnn_model11.save('cnn_model11_file3.h5')

# %% [markdown]
# ***Model #2. Multi-layer Perceptron. Keras***

# %%
def mlp_model():
    model_input = Input(shape=(784,))
    x = BatchNormalization()(model_input)
    
    x = Dense(784, activation='relu')(x)
    
    x = Dropout(0.5)(x)

    x = Dense(1568, activation='relu')(x)
    
    x = Dropout(0.5)(x)

    y = Dense(10, activation='softmax')(x)
    
    model = Model(input=model_input, output=y)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
mlp_model = mlp_model()    

fit12 = mlp_model.fit(X_train2, y_train2, validation_data=(X_test2, y_test2), 
                      epochs=10, batch_size=56, verbose=2);
# Out:
# Train on 33600 samples, validate on 8400 samples
# Epoch 1/20
# 54s - loss: 0.3704 - acc: 0.8888 - val_loss: 0.1899 - val_acc: 0.9501
# Epoch 2/20
# 50s - loss: 0.1973 - acc: 0.9407 - val_loss: 0.1458 - val_acc: 0.9606
# Epoch 3/20
# 50s - loss: 0.1651 - acc: 0.9500 - val_loss: 0.1267 - val_acc: 0.9639
# Epoch 4/20
# 50s - loss: 0.1441 - acc: 0.9563 - val_loss: 0.1363 - val_acc: 0.9652
# Epoch 5/20
# 48s - loss: 0.1273 - acc: 0.9629 - val_loss: 0.1241 - val_acc: 0.9685
# Epoch 6/20
# 47s - loss: 0.1334 - acc: 0.9618 - val_loss: 0.1279 - val_acc: 0.9693
# Epoch 7/20
# 51s - loss: 0.1196 - acc: 0.9649 - val_loss: 0.1283 - val_acc: 0.9695
# Epoch 8/20
# 51s - loss: 0.1102 - acc: 0.9680 - val_loss: 0.1279 - val_acc: 0.9720
# Epoch 9/20
# 56s - loss: 0.1112 - acc: 0.9693 - val_loss: 0.1107 - val_acc: 0.9727
# Epoch 10/20
# 55s - loss: 0.1056 - acc: 0.9711 - val_loss: 0.1111 - val_acc: 0.9740
# Epoch 11/20
# 49s - loss: 0.1042 - acc: 0.9725 - val_loss: 0.1166 - val_acc: 0.9736
# Epoch 12/20
# 49s - loss: 0.1036 - acc: 0.9710 - val_loss: 0.1326 - val_acc: 0.9707
# Epoch 13/20
# 51s - loss: 0.1029 - acc: 0.9721 - val_loss: 0.1157 - val_acc: 0.9729
# Epoch 14/20
# 48s - loss: 0.0968 - acc: 0.9745 - val_loss: 0.1353 - val_acc: 0.9733
# Epoch 15/20
# 53s - loss: 0.0924 - acc: 0.9753 - val_loss: 0.1212 - val_acc: 0.9736
# Epoch 16/20
# 54s - loss: 0.0977 - acc: 0.9743 - val_loss: 0.1119 - val_acc: 0.9736
# Epoch 17/20
# 49s - loss: 0.0891 - acc: 0.9766 - val_loss: 0.1316 - val_acc: 0.9707
# Epoch 18/20
# 50s - loss: 0.0904 - acc: 0.9776 - val_loss: 0.1277 - val_acc: 0.9751
# Epoch 19/20
# 55s - loss: 0.0913 - acc: 0.9765 - val_loss: 0.1267 - val_acc: 0.9725
# Epoch 20/20
# 50s - loss: 0.0945 - acc: 0.9773 - val_loss: 0.1235 - val_acc: 0.9717

# %%
plt.figure(figsize=(18,5))
plt.plot(fit12.history['acc'], '-o', label = 'train')
plt.plot(fit12.history['val_acc'], '-o', label = 'test')
plt.legend()
plt.title('Accuracy');

# %%
mlp_scores = mlp_model.evaluate(X_test2, y_test2)
print("\nMLP Scores: ", (mlp_scores))
print("MLP Error: %.2f%%" % (100 - mlp_scores[1] * 100))
print(mlp_model.summary())
# Out:
# 8400/8400 [==============================] - 3s
#
# MLP Scores:  [0.12352911993102972, 0.97166666666666668]
# MLP Error: 2.83%
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        (None, 784)               0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 784)               3136
# _________________________________________________________________
# dense_30 (Dense)             (None, 784)               615440
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 784)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 1568)              1230880
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 1568)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                15690
# =================================================================
# Total params: 1,865,146
# Trainable params: 1,863,578
# Non-trainable params: 1,568
# _________________________________________________________________
# None

# %%
# mlp_model.save('mlp_model_file1.h5')
mlp_model.save('mlp_model_file2.h5')

# %% [markdown]
# ***Model #3. MLPClassifier. Scikit-learn***

# %%
clf1 = MLPClassifier(hidden_layer_sizes=(784,), max_iter=20, alpha=1e-4,
                     solver='adam', verbose=1, tol=1e-5, random_state=1,
                     learning_rate_init=7e-4)
clf1.fit(X_train3, y_train3);
# Out:
# Iteration 1, loss = 2.28407251
# Iteration 2, loss = 0.78406912
# Iteration 3, loss = 0.46468680
# Iteration 4, loss = 0.30060982
# Iteration 5, loss = 0.23693306
# Iteration 6, loss = 0.20869455
# Iteration 7, loss = 0.16518901
# Iteration 8, loss = 0.18086656
# Iteration 9, loss = 0.12893494
# Iteration 10, loss = 0.12745977
# Iteration 11, loss = 0.13126303
# Iteration 12, loss = 0.11066469
# Iteration 13, loss = 0.10859862
# Iteration 14, loss = 0.09278799
# Iteration 15, loss = 0.13004827
# Iteration 16, loss = 0.08509860
# Iteration 17, loss = 0.09410732
# Iteration 18, loss = 0.13610086
# Iteration 19, loss = 0.09076005
# Training loss did not improve more than tol=0.000010 for two consecutive epochs. Stopping.

# %%
print("MNIST. MLPClassifier. Train score: %f" % (clf1.score(X_train3, y_train3)*100),'%')
print("MNIST. MLPClassifier. Test score: %f" % (clf1.score(X_test3, y_test3)*100),'%')
# Out:
# MNIST. MLPClassifier. Train score: 99.267857 %
# MNIST. MLPClassifier. Test score: 96.738095 %

# %%
clf2 = MLPClassifier(hidden_layer_sizes=(784,), max_iter=20, alpha=1e-4,
                     solver='adam', verbose=1, tol=1e-6, random_state=1,
                     learning_rate_init=7e-4, batch_size=56)
clf2.fit(X_train3, y_train3);
# Out:
# Iteration 1, loss = 1.84844139
# Iteration 2, loss = 0.56802647
# Iteration 3, loss = 0.36746840
# Iteration 4, loss = 0.31409956
# Iteration 5, loss = 0.25743568
# Iteration 6, loss = 0.27770009
# Iteration 7, loss = 0.27722100
# Iteration 8, loss = 0.23946984
# Iteration 9, loss = 0.21483641
# Iteration 10, loss = 0.20634913
# Iteration 11, loss = 0.20470909
# Iteration 12, loss = 0.17458275
# Iteration 13, loss = 0.19131687
# Iteration 14, loss = 0.16960070
# Iteration 15, loss = 0.16500821
# Iteration 16, loss = 0.17307927
# Iteration 17, loss = 0.17237728
# Iteration 18, loss = 0.14248489
# Iteration 19, loss = 0.14045717
# Iteration 20, loss = 0.12993442

# %%
print("MNIST. MLPClassifier #2. Train score: %f" % (clf2.score(X_train3, y_train3)*100),'%')
print("MNIST. MLPClassifier #2. Test score: %f" % (clf2.score(X_test3, y_test3)*100),'%')
# Out:
# MNIST. MLPClassifier #2. Train score: 99.327381 %
# MNIST. MLPClassifier #2. Test score: 97.273810 %

# %% [markdown]
# ## Predictions

# %%
predict_labels1 = cnn_model11.predict(test_images28n)
predict_labels1 = predict_labels1.argmax(axis=-1)

# %%
predict_labels1[:100]
# Out:
# array([2, 0, 9, 9, 3, 7, 0, 3, 0, 3, 5, 7, 4, 0, 4, 3, 3, 1, 9, 0, 9, 1, 1,
#        5, 7, 4, 2, 7, 4, 7, 7, 5, 4, 2, 6, 2, 5, 5, 1, 6, 7, 7, 4, 9, 8, 7,
#        8, 2, 6, 7, 6, 8, 8, 3, 8, 2, 1, 2, 2, 0, 4, 1, 7, 0, 0, 0, 1, 9, 0,
#        1, 6, 5, 8, 8, 2, 8, 9, 9, 2, 3, 5, 4, 1, 0, 9, 2, 4, 3, 6, 7, 2, 0,
#        6, 6, 1, 4, 3, 9, 7, 4])

# %%
predict_labels2 = mlp_model.predict(test_images)
predict_labels2 = predict_labels2.argmax(axis=-1)

# %%
predict_labels2[:100]
# Out:
# array([2, 0, 9, 9, 3, 7, 0, 3, 0, 3, 5, 7, 4, 0, 4, 3, 3, 1, 9, 0, 9, 1, 1,
#        5, 7, 4, 2, 7, 4, 7, 7, 5, 4, 2, 6, 2, 5, 5, 1, 6, 7, 7, 4, 9, 8, 7,
#        8, 2, 6, 7, 6, 8, 8, 3, 8, 2, 1, 2, 2, 0, 4, 1, 7, 0, 0, 0, 1, 9, 0,
#        1, 6, 5, 8, 8, 2, 8, 8, 9, 2, 3, 5, 4, 1, 0, 9, 2, 4, 3, 6, 7, 2, 0,
#        6, 6, 1, 4, 3, 9, 7, 4])

# %%
predict_labels3 = clf1.predict(test_images)

# %%
submission1 = pd.DataFrame({"ImageId": range(1, len(predict_labels1)+1), "Label": predict_labels1})
print(submission1[0:10])

submission1.to_csv('kaggle_digits_model1_3.csv', index=False)
# Out:
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      9
# 4        5      3
# 5        6      7
# 6        7      0
# 7        8      3
# 8        9      0
# 9       10      3

# %%
submission2 = pd.DataFrame({"ImageId": range(1, len(predict_labels2)+1), "Label": predict_labels2})
print(submission2[100:120])

submission2.to_csv('kaggle_digits_model2.csv', index=False)
# Out:
#      ImageId  Label
# 100      101      0
# 101      102      8
# 102      103      2
# 103      104      0
# 104      105      7
# 105      106      3
# 106      107      0
# 107      108      5
# 108      109      0
# 109      110      8
# 110      111      0
# 111      112      0
# 112      113      4
# 113      114      7
# 114      115      1
# 115      116      7
# 116      117      1
# 117      118      1
# 118      119      3
# 119      120      3

# %%
submission3 = pd.DataFrame({"ImageId": range(1, len(predict_labels3)+1), "Label": predict_labels3})
print(submission3[100:120])

submission3.to_csv('kaggle_digits_model3.csv', index=False)
# Out:
#      ImageId  Label
# 100      101      0
# 101      102      9
# 102      103      2
# 103      104      0
# 104      105      7
# 105      106      3
# 106      107      0
# 107      108      5
# 108      109      0
# 109      110      8
# 110      111      0
# 111      112      0
# 112      113      4
# 113      114      7
# 114      115      1
# 115      116      7
# 116      117      1
# 117      118      1
# 118      119      3
# 119      120      3

# %%
real_data = np.array([2, 0, 9, 0, 3, 7, 0, 3, 0, 3,
                      5, 7, 4, 0, 4, 3, 3, 1, 9, 0,
                      9, 1, 1, 5, 7, 4, 2, 7, 4, 7,
                      7, 5, 4, 2, 6, 2, 5, 5, 1, 6,
                      7, 7, 4, 9, 8, 7, 8, 2, 6, 7,
                      6, 8, 8, 3, 8, 2, 1, 2, 2, 0,
                      4, 1, 7, 0, 0, 0, 1, 9, 0, 1,
                      6, 5, 8, 8, 2, 8, 9, 9, 2, 3,
                      5, 4, 1, 0, 9, 2, 4, 3, 6, 7,
                      2, 0, 6, 6, 1, 4, 3, 9, 7, 4])

# %%
plt.figure(figsize = (18, 9))

plt.plot(submission1['Label'][0:100], '-o', label='#1')
#plt.plot(submission2['Label'][0:100], '-o', label='#2')
plt.plot(real_data[0:100], '-o', label='Real Data')

plt.legend()
plt.title("Predictions");

# %%
fig, ax = plt.subplots(figsize=(18, 10), nrows=5, ncols=10, sharex=True, sharey=True,)
ax = ax.flatten()
for i in range(50):
    image = test_images28[28:100][i]
    ax[i].imshow(image, cmap=plt.cm.Blues)

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.gcf()
ax[4].set_title('Examples of the 784-dimensional digits. Test datapoints', fontsize=25);
