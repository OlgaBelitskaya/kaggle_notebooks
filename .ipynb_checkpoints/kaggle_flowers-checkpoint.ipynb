# %% [markdown]
# # &#x1F4D1; &nbsp;  The Data Set of Flower Images

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron');
# body {background-color: gainsboro;}
# a {color: #818286; font-family: Orbitron;}
# h1, h2 {color: #37c9e1; font-family: Orbitron; text-shadow: 4px 4px 4px #aaa;}
# h3, h4 {color: #818286; font-family: Orbitron; text-shadow: 4px 4px 4px #aaa;}
# </style>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron');
# body {background-color: gainsboro;}
# a {color: #818286; font-family: Orbitron;}
# h1, h2 {color: #37c9e1; font-family: Orbitron; text-shadow: 4px 4px 4px #aaa;}
# h3, h4 {color: #818286; font-family: Orbitron; text-shadow: 4px 4px 4px #aaa;}
# </style>

# %% [markdown]
# ## &#x1F310; &nbsp; 0. Code Library and Links

# %%
import numpy as np 
import pandas as pd 

import cv2
import scipy
from skimage import io

from PIL import ImageFile
from tqdm import tqdm

# %%
import matplotlib.pylab as plt
from matplotlib import cm
# %matplotlib inline

# %%
from keras.preprocessing import image as keras_image
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input as inception_v3_preprocess_input

from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, LSTM, GlobalAveragePooling1D
from keras.layers import Activation, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D

# %%
def loss_plot(fit_history):
    plt.figure(figsize=(18, 4))

    plt.plot(fit_history.history['loss'], label = 'train')
    plt.plot(fit_history.history['val_loss'], label = 'test')

    plt.legend()
    plt.title('Loss Function');  

def acc_plot(fit_history):
    plt.figure(figsize=(18, 4))

    plt.plot(fit_history.history['acc'], label = 'train')
    plt.plot(fit_history.history['val_acc'], label = 'test')

    plt.legend()
    plt.title('Accuracy'); 
    
def path_to_tensor(img_path):
    img = keras_image.load_img("/Users/olgabelitskaya/cookbooks/flower_images/"+img_path, 
                               target_size=(128, 128))
    x = keras_image.img_to_array(img)
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# ## &#x1F310; &nbsp; 1. Explore the Data

# %%
flowers = pd.read_csv("/Users/olgabelitskaya/cookbooks/flower_images/flower_labels.csv")
flower_files = flowers['file']
flower_targets = flowers['label'].as_matrix()
flower_tensors = paths_to_tensor(flower_files);
# Out:
# 100%|██████████| 210/210 [00:08<00:00, 24.42it/s]

# %%
print('Label: ', flower_targets[168])
flower_image = cv2.imread('/Users/olgabelitskaya/cookbooks/flower_images/'+flower_files[168])
rgb_flower_image = cv2.cvtColor(flower_image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(3,3))
plt.imshow(rgb_flower_image);
# Out:
# Label:  9

# %%
x_train, x_test, y_train, y_test = train_test_split(flower_tensors, flower_targets, 
                                                    test_size = 0.1, random_state = 1)
[x_train.shape, y_train.shape, x_test.shape, y_test.shape]
# Out:
# [(189, 128, 128, 3), (189,), (21, 128, 128, 3), (21,)]

# %%
print('Label: ', y_train[1])
plt.figure(figsize=(3,3))
plt.imshow((x_train[1]/255).reshape(128,128,3));
# Out:
# Label:  3

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

c_y_train = to_categorical(y_train, 10)
c_y_test = to_categorical(y_test, 10)

[x_train.shape, c_y_train.shape, x_test.shape, c_y_test.shape]
# Out:
# [(189, 128, 128, 3), (189, 10), (21, 128, 128, 3), (21, 10)]

# %% [markdown]
# ## &#x1F310; &nbsp; 2. Models

# %%
# MLP
def mlp_mc_model():
    model = Sequential()
    
    model.add(Dense(128, activation='relu', input_shape=(128*128*3,)))
    
    model.add(Dense(256, activation='relu'))
    model.add(Dense(256, activation='relu'))
    
    model.add(Dense(562, activation='relu'))
    model.add(Dense(562, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

mlp_mc_model = mlp_mc_model()

# %%
mlp_mc_checkpointer = ModelCheckpoint(filepath='weights.best.mlp_mc.flowers.hdf5', 
                                      verbose=2, save_best_only=True)
mlp_mc_history = mlp_mc_model.fit(x_train.reshape(-1, 128*128*3), c_y_train,
                                  validation_data=(x_test.reshape(-1, 128*128*3), c_y_test),
                                  epochs=25, batch_size=64, verbose=2, 
                                  callbacks=[mlp_mc_checkpointer])
# Out:
# Train on 189 samples, validate on 21 samples
# Epoch 1/25
# Epoch 00000: val_loss improved from inf to 2.98226, saving model to weights.best.mlp_mc.flowers.hdf5
# 5s - loss: 4.9457 - acc: 0.1058 - val_loss: 2.9823 - val_acc: 0.1905
# Epoch 2/25
# Epoch 00001: val_loss improved from 2.98226 to 2.90492, saving model to weights.best.mlp_mc.flowers.hdf5
# 3s - loss: 4.6047 - acc: 0.1746 - val_loss: 2.9049 - val_acc: 0.0476
# Epoch 3/25
# Epoch 00002: val_loss improved from 2.90492 to 2.27332, saving model to weights.best.mlp_mc.flowers.hdf5
# 3s - loss: 3.6024 - acc: 0.1799 - val_loss: 2.2733 - val_acc: 0.3333
# Epoch 4/25
# Epoch 00003: val_loss improved from 2.27332 to 1.92220, saving model to weights.best.mlp_mc.flowers.hdf5
# 4s - loss: 2.9218 - acc: 0.1587 - val_loss: 1.9222 - val_acc: 0.2381
# Epoch 5/25
# Epoch 00004: val_loss did not improve
# 0s - loss: 2.1751 - acc: 0.2487 - val_loss: 2.0371 - val_acc: 0.3810
# Epoch 6/25
# Epoch 00005: val_loss improved from 1.92220 to 1.71223, saving model to weights.best.mlp_mc.flowers.hdf5
# 4s - loss: 1.8118 - acc: 0.3915 - val_loss: 1.7122 - val_acc: 0.4286
# Epoch 7/25
# Epoch 00006: val_loss improved from 1.71223 to 1.59734, saving model to weights.best.mlp_mc.flowers.hdf5
# 4s - loss: 1.6457 - acc: 0.4392 - val_loss: 1.5973 - val_acc: 0.4762
# Epoch 8/25
# Epoch 00007: val_loss improved from 1.59734 to 1.56013, saving model to weights.best.mlp_mc.flowers.hdf5
# 5s - loss: 1.4346 - acc: 0.5185 - val_loss: 1.5601 - val_acc: 0.4286
# Epoch 9/25
# Epoch 00008: val_loss improved from 1.56013 to 1.35047, saving model to weights.best.mlp_mc.flowers.hdf5
# 3s - loss: 1.2371 - acc: 0.5767 - val_loss: 1.3505 - val_acc: 0.5238
# Epoch 10/25
# Epoch 00009: val_loss did not improve
# 0s - loss: 1.1175 - acc: 0.5979 - val_loss: 1.4190 - val_acc: 0.3810
# Epoch 11/25
# Epoch 00010: val_loss did not improve
# 0s - loss: 1.1706 - acc: 0.5556 - val_loss: 1.4256 - val_acc: 0.4286
# Epoch 12/25
# Epoch 00011: val_loss improved from 1.35047 to 1.28299, saving model to weights.best.mlp_mc.flowers.hdf5
# 2s - loss: 0.8854 - acc: 0.6878 - val_loss: 1.2830 - val_acc: 0.4286
# Epoch 13/25
# Epoch 00012: val_loss did not improve
# 0s - loss: 0.8864 - acc: 0.6825 - val_loss: 1.2909 - val_acc: 0.6190
# Epoch 14/25
# Epoch 00013: val_loss improved from 1.28299 to 1.24918, saving model to weights.best.mlp_mc.flowers.hdf5
# 3s - loss: 0.8659 - acc: 0.6561 - val_loss: 1.2492 - val_acc: 0.5238
# Epoch 15/25
# Epoch 00014: val_loss did not improve
# 0s - loss: 0.7189 - acc: 0.7354 - val_loss: 1.7414 - val_acc: 0.4762
# Epoch 16/25
# Epoch 00015: val_loss did not improve
# 0s - loss: 0.6816 - acc: 0.7672 - val_loss: 1.3101 - val_acc: 0.4762
# Epoch 17/25
# Epoch 00016: val_loss did not improve
# 0s - loss: 0.6064 - acc: 0.7725 - val_loss: 1.4292 - val_acc: 0.4286
# Epoch 18/25
# Epoch 00017: val_loss did not improve
# 0s - loss: 0.5437 - acc: 0.7989 - val_loss: 1.2512 - val_acc: 0.6190
# Epoch 19/25
# Epoch 00018: val_loss improved from 1.24918 to 1.21401, saving model to weights.best.mlp_mc.flowers.hdf5
# 3s - loss: 0.4620 - acc: 0.8095 - val_loss: 1.2140 - val_acc: 0.5238
# Epoch 20/25
# Epoch 00019: val_loss did not improve
# 0s - loss: 0.3010 - acc: 0.9048 - val_loss: 1.4950 - val_acc: 0.5714
# Epoch 21/25
# Epoch 00020: val_loss improved from 1.21401 to 1.08364, saving model to weights.best.mlp_mc.flowers.hdf5
# 3s - loss: 0.2717 - acc: 0.8995 - val_loss: 1.0836 - val_acc: 0.6667
# Epoch 22/25
# Epoch 00021: val_loss did not improve
# 0s - loss: 0.1636 - acc: 0.9577 - val_loss: 1.3685 - val_acc: 0.5238
# Epoch 23/25
# Epoch 00022: val_loss did not improve
# 0s - loss: 0.1562 - acc: 0.9418 - val_loss: 1.2749 - val_acc: 0.5714
# Epoch 24/25
# Epoch 00023: val_loss did not improve
# 0s - loss: 0.0848 - acc: 0.9841 - val_loss: 1.5580 - val_acc: 0.4762
# Epoch 25/25
# Epoch 00024: val_loss did not improve
# 0s - loss: 0.0824 - acc: 0.9788 - val_loss: 1.3784 - val_acc: 0.6190

# %%
loss_plot(mlp_mc_history)
acc_plot(mlp_mc_history)

# %%
mlp_mc_model.load_weights('weights.best.mlp_mc.flowers.hdf5')
mlp_mc_test_score = mlp_mc_model.evaluate(x_test.reshape(-1, 128*128*3), c_y_test)
mlp_mc_test_score
# Out:
# 21/21 [==============================] - 0s
# [1.0836354494094849, 0.66666668653488159]

# %%
# CNN
def cnn_mc_model():
    model = Sequential()

    model.add(Conv2D(32, (5, 5), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(96, (5, 5)))
    model.add(Activation('relu'))
    
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5)) 

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

cnn_mc_model = cnn_mc_model()

# %%
cnn_mc_checkpointer = ModelCheckpoint(filepath='weights.best.cnn_mc.flowers.hdf5', 
                                      verbose=2, save_best_only=True)
cnn_mc_history = cnn_mc_model.fit(x_train, c_y_train, 
                                  epochs=15, batch_size=64, verbose=2,
                                  validation_data=(x_test, c_y_test),
                                  callbacks=[cnn_mc_checkpointer])
# Out:
# Train on 189 samples, validate on 21 samples
# Epoch 1/15
# Epoch 00000: val_loss improved from inf to 2.89979, saving model to weights.best.cnn_mc.flowers.hdf5
# 135s - loss: 7.9213 - acc: 0.1005 - val_loss: 2.8998 - val_acc: 0.1429
# Epoch 2/15
# Epoch 00001: val_loss improved from 2.89979 to 2.27767, saving model to weights.best.cnn_mc.flowers.hdf5
# 217s - loss: 4.4074 - acc: 0.1376 - val_loss: 2.2777 - val_acc: 0.0476
# Epoch 3/15
# Epoch 00002: val_loss improved from 2.27767 to 2.23460, saving model to weights.best.cnn_mc.flowers.hdf5
# 44s - loss: 2.2161 - acc: 0.1111 - val_loss: 2.2346 - val_acc: 0.0476
# Epoch 4/15
# Epoch 00003: val_loss improved from 2.23460 to 2.19787, saving model to weights.best.cnn_mc.flowers.hdf5
# 87s - loss: 2.1481 - acc: 0.1429 - val_loss: 2.1979 - val_acc: 0.3333
# Epoch 5/15
# Epoch 00004: val_loss improved from 2.19787 to 2.10753, saving model to weights.best.cnn_mc.flowers.hdf5
# 38s - loss: 2.0545 - acc: 0.2910 - val_loss: 2.1075 - val_acc: 0.2857
# Epoch 6/15
# Epoch 00005: val_loss improved from 2.10753 to 1.89891, saving model to weights.best.cnn_mc.flowers.hdf5
# 35s - loss: 1.9183 - acc: 0.3386 - val_loss: 1.8989 - val_acc: 0.3333
# Epoch 7/15
# Epoch 00006: val_loss improved from 1.89891 to 1.75894, saving model to weights.best.cnn_mc.flowers.hdf5
# 33s - loss: 1.6903 - acc: 0.4550 - val_loss: 1.7589 - val_acc: 0.2857
# Epoch 8/15
# Epoch 00007: val_loss improved from 1.75894 to 1.60534, saving model to weights.best.cnn_mc.flowers.hdf5
# 33s - loss: 1.5030 - acc: 0.4392 - val_loss: 1.6053 - val_acc: 0.2857
# Epoch 9/15
# Epoch 00008: val_loss improved from 1.60534 to 1.49048, saving model to weights.best.cnn_mc.flowers.hdf5
# 38s - loss: 1.3588 - acc: 0.5132 - val_loss: 1.4905 - val_acc: 0.5238
# Epoch 10/15
# Epoch 00009: val_loss improved from 1.49048 to 1.29953, saving model to weights.best.cnn_mc.flowers.hdf5
# 36s - loss: 1.2059 - acc: 0.5450 - val_loss: 1.2995 - val_acc: 0.4762
# Epoch 11/15
# Epoch 00010: val_loss did not improve
# 21s - loss: 1.0280 - acc: 0.6349 - val_loss: 1.4480 - val_acc: 0.4762
# Epoch 12/15
# Epoch 00011: val_loss improved from 1.29953 to 1.25592, saving model to weights.best.cnn_mc.flowers.hdf5
# 36s - loss: 0.9871 - acc: 0.6508 - val_loss: 1.2559 - val_acc: 0.4762
# Epoch 13/15
# Epoch 00012: val_loss improved from 1.25592 to 1.20960, saving model to weights.best.cnn_mc.flowers.hdf5
# 34s - loss: 0.7728 - acc: 0.7672 - val_loss: 1.2096 - val_acc: 0.5714
# Epoch 14/15
# Epoch 00013: val_loss improved from 1.20960 to 1.06532, saving model to weights.best.cnn_mc.flowers.hdf5
# 27s - loss: 0.6565 - acc: 0.7831 - val_loss: 1.0653 - val_acc: 0.8095
# Epoch 15/15
# Epoch 00014: val_loss did not improve
# 16s - loss: 0.6234 - acc: 0.7725 - val_loss: 1.3251 - val_acc: 0.4286

# %%
loss_plot(cnn_mc_history)
acc_plot(cnn_mc_history)

# %%
cnn_mc_model.load_weights('weights.best.cnn_mc.flowers.hdf5')
cnn_mc_test_score = cnn_mc_model.evaluate(x_test, c_y_test)
cnn_mc_test_score
# Out:
# 21/21 [==============================] - 0s
# [1.0653198957443237, 0.8095238208770752]

# %%
data_generator = keras_image.ImageDataGenerator(shear_range=0.2, 
                                                zoom_range=0.2,
                                                rotation_range=30,
                                                horizontal_flip=True)
cnn_mc_dg_history = cnn_mc_model.fit_generator(data_generator.flow(x_train, c_y_train, batch_size=64),
                                               steps_per_epoch = 150, epochs = 10, verbose=2, 
                                               validation_data = (x_test, c_y_test),
                                               callbacks=[cnn_mc_checkpointer])
# Out:
# Epoch 1/10
# Epoch 00000: val_loss improved from 1.06532 to 0.83725, saving model to weights.best.cnn_mc.flowers.hdf5
# 831s - loss: 0.5832 - acc: 0.8016 - val_loss: 0.8372 - val_acc: 0.8095
# Epoch 2/10
# Epoch 00001: val_loss did not improve
# 788s - loss: 0.2587 - acc: 0.9129 - val_loss: 1.1233 - val_acc: 0.8571
# Epoch 3/10
# Epoch 00002: val_loss did not improve
# 768s - loss: 0.1380 - acc: 0.9536 - val_loss: 1.4384 - val_acc: 0.8571
# Epoch 4/10
# Epoch 00003: val_loss did not improve
# 795s - loss: 0.0991 - acc: 0.9674 - val_loss: 1.4969 - val_acc: 0.7619
# Epoch 5/10
# Epoch 00004: val_loss did not improve
# 776s - loss: 0.0939 - acc: 0.9693 - val_loss: 1.6750 - val_acc: 0.7619
# Epoch 6/10
# Epoch 00005: val_loss did not improve
# 790s - loss: 0.0698 - acc: 0.9765 - val_loss: 1.8115 - val_acc: 0.7619
# Epoch 7/10
# Epoch 00006: val_loss did not improve
# 794s - loss: 0.0655 - acc: 0.9810 - val_loss: 2.0593 - val_acc: 0.6667
# Epoch 8/10
# Epoch 00007: val_loss did not improve
# 792s - loss: 0.0497 - acc: 0.9821 - val_loss: 2.0561 - val_acc: 0.8095
# Epoch 9/10
# Epoch 00008: val_loss did not improve
# 803s - loss: 0.0583 - acc: 0.9823 - val_loss: 1.9407 - val_acc: 0.8095
# Epoch 10/10
# Epoch 00009: val_loss did not improve
# 831s - loss: 0.0512 - acc: 0.9824 - val_loss: 1.6841 - val_acc: 0.8571

# %%
loss_plot(cnn_mc_dg_history)
acc_plot(cnn_mc_dg_history)

# %%
cnn_mc_model.load_weights('weights.best.cnn_mc.flowers.hdf5')
cnn_mc_dg_test_score = cnn_mc_model.evaluate(x_test, c_y_test)
cnn_mc_dg_test_score
# Out:
# 21/21 [==============================] - 0s
# [0.83724814653396606, 0.8095238208770752]

# %%
# RNN
def rnn_mc_model():
    model = Sequential()

    model.add(LSTM(128, return_sequences=True, input_shape=(1, 128*128*3))) 
#    model.add(LSTM(128, return_sequences=True))
    
    model.add(LSTM(128))  
    model.add(Dense(512, activation='tanh'))
    
    model.add(Dense(10, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])    
    return model

rnn_mc_model = rnn_mc_model()

# %%
rnn_mc_checkpointer = ModelCheckpoint(filepath='weights.best.rnn_mc.flowers.hdf5', 
                                      verbose=2, save_best_only=True)
rnn_mc_history = rnn_mc_model.fit(x_train.reshape(-1,1,128*128*3), c_y_train, 
                                  epochs=30, batch_size=64, verbose=2,
                                  validation_data=(x_test.reshape(-1,1,128*128*3), c_y_test),
                                  callbacks=[rnn_mc_checkpointer])
# Out:
# Train on 189 samples, validate on 21 samples
# Epoch 1/30
# Epoch 00000: val_loss improved from inf to 2.28176, saving model to weights.best.rnn_mc.flowers.hdf5
# 34s - loss: 2.3099 - acc: 0.0794 - val_loss: 2.2818 - val_acc: 0.1905
# Epoch 2/30
# Epoch 00001: val_loss improved from 2.28176 to 2.25892, saving model to weights.best.rnn_mc.flowers.hdf5
# 16s - loss: 2.2710 - acc: 0.1640 - val_loss: 2.2589 - val_acc: 0.0952
# Epoch 3/30
# Epoch 00002: val_loss improved from 2.25892 to 2.21680, saving model to weights.best.rnn_mc.flowers.hdf5
# 14s - loss: 2.2286 - acc: 0.1746 - val_loss: 2.2168 - val_acc: 0.0952
# Epoch 4/30
# Epoch 00003: val_loss improved from 2.21680 to 2.17493, saving model to weights.best.rnn_mc.flowers.hdf5
# 17s - loss: 2.1892 - acc: 0.2328 - val_loss: 2.1749 - val_acc: 0.2381
# Epoch 5/30
# Epoch 00004: val_loss improved from 2.17493 to 2.11627, saving model to weights.best.rnn_mc.flowers.hdf5
# 20s - loss: 2.1169 - acc: 0.2910 - val_loss: 2.1163 - val_acc: 0.2381
# Epoch 6/30
# Epoch 00005: val_loss improved from 2.11627 to 2.07199, saving model to weights.best.rnn_mc.flowers.hdf5
# 20s - loss: 2.0252 - acc: 0.3598 - val_loss: 2.0720 - val_acc: 0.2857
# Epoch 7/30
# Epoch 00006: val_loss improved from 2.07199 to 1.98681, saving model to weights.best.rnn_mc.flowers.hdf5
# 20s - loss: 1.9428 - acc: 0.3810 - val_loss: 1.9868 - val_acc: 0.2857
# Epoch 8/30
# Epoch 00007: val_loss did not improve
# 3s - loss: 1.8540 - acc: 0.3545 - val_loss: 2.0214 - val_acc: 0.2381
# Epoch 9/30
# Epoch 00008: val_loss improved from 1.98681 to 1.90578, saving model to weights.best.rnn_mc.flowers.hdf5
# 29s - loss: 1.7219 - acc: 0.3915 - val_loss: 1.9058 - val_acc: 0.2857
# Epoch 10/30
# Epoch 00009: val_loss did not improve
# 7s - loss: 1.6712 - acc: 0.4497 - val_loss: 1.9348 - val_acc: 0.2857
# Epoch 11/30
# Epoch 00010: val_loss did not improve
# 3s - loss: 1.6643 - acc: 0.4709 - val_loss: 2.0458 - val_acc: 0.2381
# Epoch 12/30
# Epoch 00011: val_loss improved from 1.90578 to 1.83861, saving model to weights.best.rnn_mc.flowers.hdf5
# 25s - loss: 1.6296 - acc: 0.3704 - val_loss: 1.8386 - val_acc: 0.2857
# Epoch 13/30
# Epoch 00012: val_loss did not improve
# 3s - loss: 1.5627 - acc: 0.3757 - val_loss: 2.0662 - val_acc: 0.2381
# Epoch 14/30
# Epoch 00013: val_loss did not improve
# 3s - loss: 1.6019 - acc: 0.3545 - val_loss: 1.8728 - val_acc: 0.3333
# Epoch 15/30
# Epoch 00014: val_loss improved from 1.83861 to 1.66635, saving model to weights.best.rnn_mc.flowers.hdf5
# 26s - loss: 1.5645 - acc: 0.4286 - val_loss: 1.6663 - val_acc: 0.3810
# Epoch 16/30
# Epoch 00015: val_loss did not improve
# 4s - loss: 1.5780 - acc: 0.4444 - val_loss: 1.8090 - val_acc: 0.3810
# Epoch 17/30
# Epoch 00016: val_loss did not improve
# 5s - loss: 1.5105 - acc: 0.4286 - val_loss: 1.7416 - val_acc: 0.3333
# Epoch 18/30
# Epoch 00017: val_loss improved from 1.66635 to 1.64123, saving model to weights.best.rnn_mc.flowers.hdf5
# 28s - loss: 1.4050 - acc: 0.5026 - val_loss: 1.6412 - val_acc: 0.5238
# Epoch 19/30
# Epoch 00018: val_loss did not improve
# 6s - loss: 1.3655 - acc: 0.5503 - val_loss: 1.6627 - val_acc: 0.3810
# Epoch 20/30
# Epoch 00019: val_loss improved from 1.64123 to 1.62721, saving model to weights.best.rnn_mc.flowers.hdf5
# 28s - loss: 1.2986 - acc: 0.5767 - val_loss: 1.6272 - val_acc: 0.3810
# Epoch 21/30
# Epoch 00020: val_loss did not improve
# 2s - loss: 1.2830 - acc: 0.5503 - val_loss: 1.6367 - val_acc: 0.4286
# Epoch 22/30
# Epoch 00021: val_loss did not improve
# 2s - loss: 1.2678 - acc: 0.5714 - val_loss: 1.6604 - val_acc: 0.2381
# Epoch 23/30
# Epoch 00022: val_loss did not improve
# 2s - loss: 1.2073 - acc: 0.5767 - val_loss: 1.6516 - val_acc: 0.5238
# Epoch 24/30
# Epoch 00023: val_loss improved from 1.62721 to 1.50038, saving model to weights.best.rnn_mc.flowers.hdf5
# 37s - loss: 1.1980 - acc: 0.5291 - val_loss: 1.5004 - val_acc: 0.5238
# Epoch 25/30
# Epoch 00024: val_loss improved from 1.50038 to 1.46583, saving model to weights.best.rnn_mc.flowers.hdf5
# 47s - loss: 1.1366 - acc: 0.5926 - val_loss: 1.4658 - val_acc: 0.5714
# Epoch 26/30
# Epoch 00025: val_loss did not improve
# 2s - loss: 1.2396 - acc: 0.5979 - val_loss: 1.8009 - val_acc: 0.4286
# Epoch 27/30
# Epoch 00026: val_loss did not improve
# 2s - loss: 1.3422 - acc: 0.5079 - val_loss: 2.0223 - val_acc: 0.3333
# Epoch 28/30
# Epoch 00027: val_loss did not improve
# 2s - loss: 1.3261 - acc: 0.5238 - val_loss: 1.6729 - val_acc: 0.4762
# Epoch 29/30
# Epoch 00028: val_loss did not improve
# 2s - loss: 1.3719 - acc: 0.4868 - val_loss: 1.7536 - val_acc: 0.5238
# Epoch 30/30
# Epoch 00029: val_loss did not improve
# 2s - loss: 1.2991 - acc: 0.5238 - val_loss: 1.7978 - val_acc: 0.4286

# %%
loss_plot(rnn_mc_history)
acc_plot(rnn_mc_history)

# %%
rnn_mc_model.load_weights('weights.best.rnn_mc.flowers.hdf5')
rnn_mc_test_score = rnn_mc_model.evaluate(x_test.reshape(-1,1,128*128*3), c_y_test)
rnn_mc_test_score
# Out:
# 21/21 [==============================] - 0s
# [1.4658287763595581, 0.57142859697341919]

# %% [markdown]
# ## &#x1F310; &nbsp; 3. Applications

# %%
# InceptionV3
iv3_base_model = InceptionV3(weights='imagenet', include_top=False)
x = iv3_base_model.output

x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)

y = Dense(10, activation='softmax')(x)

iv3_model = Model(inputs=iv3_base_model.input, outputs=y)

# %%
# Freeze InceptionV3 convolutional layers
for layer in iv3_base_model.layers:
    layer.trainable = False
    
iv3_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
steps, epochs = 150, 10
data_generator = keras_image.ImageDataGenerator(shear_range=0.2, 
                                                zoom_range=0.2, 
                                                horizontal_flip=True)

# %%
iv3_history = iv3_model.fit_generator(data_generator.flow(x_train, c_y_train, batch_size=64),
                                      steps_per_epoch = steps, epochs = epochs, verbose=2, 
                                      validation_data = (x_test, c_y_test))
# Out:
# Epoch 1/10
# 740s - loss: 0.6370 - acc: 0.8119 - val_loss: 1.9297 - val_acc: 0.5238
# Epoch 2/10
# 710s - loss: 0.2400 - acc: 0.9288 - val_loss: 1.0962 - val_acc: 0.7143
# Epoch 3/10
# 721s - loss: 0.1535 - acc: 0.9546 - val_loss: 1.2874 - val_acc: 0.7619
# Epoch 4/10
# 708s - loss: 0.1357 - acc: 0.9580 - val_loss: 1.4780 - val_acc: 0.6667
# Epoch 5/10
# 725s - loss: 0.1342 - acc: 0.9570 - val_loss: 1.4410 - val_acc: 0.6190
# Epoch 6/10
# 785s - loss: 0.1110 - acc: 0.9652 - val_loss: 1.2136 - val_acc: 0.7619
# Epoch 7/10
# 812s - loss: 0.1027 - acc: 0.9699 - val_loss: 1.0086 - val_acc: 0.7143
# Epoch 8/10
# 758s - loss: 0.0859 - acc: 0.9724 - val_loss: 1.1999 - val_acc: 0.6667
# Epoch 9/10
# 711s - loss: 0.0859 - acc: 0.9730 - val_loss: 1.2304 - val_acc: 0.6667
# Epoch 10/10
# 698s - loss: 0.0830 - acc: 0.9752 - val_loss: 0.8310 - val_acc: 0.6190

# %%
for i, layer in enumerate(iv3_base_model.layers[173:]):
    print(i, layer.name)
# Out:
# 0 batch_normalization_52
# 1 batch_normalization_57
# 2 activation_63
# 3 activation_68
# 4 conv2d_61
# 5 conv2d_66
# 6 batch_normalization_53
# 7 batch_normalization_58
# 8 activation_64
# 9 activation_69
# 10 average_pooling2d_6
# 11 conv2d_59
# 12 conv2d_62
# 13 conv2d_67
# 14 conv2d_68
# 15 batch_normalization_51
# 16 batch_normalization_54
# 17 batch_normalization_59
# 18 batch_normalization_60
# 19 activation_62
# 20 activation_65
# 21 activation_70
# 22 activation_71
# 23 mixed6
# 24 conv2d_73
# 25 batch_normalization_65
# 26 activation_76
# 27 conv2d_74
# 28 batch_normalization_66
# 29 activation_77
# 30 conv2d_70
# 31 conv2d_75
# 32 batch_normalization_62
# 33 batch_normalization_67
# 34 activation_73
# 35 activation_78
# 36 conv2d_71
# 37 conv2d_76
# 38 batch_normalization_63
# 39 batch_normalization_68
# 40 activation_74
# 41 activation_79
# 42 average_pooling2d_7
# 43 conv2d_69
# 44 conv2d_72
# 45 conv2d_77
# 46 conv2d_78
# 47 batch_normalization_61
# 48 batch_normalization_64
# 49 batch_normalization_69
# 50 batch_normalization_70
# 51 activation_72
# 52 activation_75
# 53 activation_80
# 54 activation_81
# 55 mixed7
# 56 conv2d_81
# 57 batch_normalization_73
# 58 activation_84
# 59 conv2d_82
# 60 batch_normalization_74
# 61 activation_85
# 62 conv2d_79
# 63 conv2d_83
# 64 batch_normalization_71
# 65 batch_normalization_75
# 66 activation_82
# 67 activation_86
# 68 conv2d_80
# 69 conv2d_84
# 70 batch_normalization_72
# 71 batch_normalization_76
# 72 activation_83
# 73 activation_87
# 74 max_pooling2d_10
# 75 mixed8
# 76 conv2d_89
# 77 batch_normalization_81
# 78 activation_92
# 79 conv2d_86
# 80 conv2d_90
# 81 batch_normalization_78
# 82 batch_normalization_82
# 83 activation_89
# 84 activation_93
# 85 conv2d_87
# 86 conv2d_88
# 87 conv2d_91
# 88 conv2d_92
# 89 average_pooling2d_8
# 90 conv2d_85
# 91 batch_normalization_79
# 92 batch_normalization_80
# 93 batch_normalization_83
# 94 batch_normalization_84
# 95 conv2d_93
# 96 batch_normalization_77
# 97 activation_90
# 98 activation_91
# 99 activation_94
# 100 activation_95
# 101 batch_normalization_85
# 102 activation_88
# 103 mixed9_0
# 104 concatenate_1
# 105 activation_96
# 106 mixed9
# 107 conv2d_98
# 108 batch_normalization_90
# 109 activation_101
# 110 conv2d_95
# 111 conv2d_99
# 112 batch_normalization_87
# 113 batch_normalization_91
# 114 activation_98
# 115 activation_102
# 116 conv2d_96
# 117 conv2d_97
# 118 conv2d_100
# 119 conv2d_101
# 120 average_pooling2d_9
# 121 conv2d_94
# 122 batch_normalization_88
# 123 batch_normalization_89
# 124 batch_normalization_92
# 125 batch_normalization_93
# 126 conv2d_102
# 127 batch_normalization_86
# 128 activation_99
# 129 activation_100
# 130 activation_103
# 131 activation_104
# 132 batch_normalization_94
# 133 activation_97
# 134 mixed9_1
# 135 concatenate_2
# 136 activation_105
# 137 mixed10

# %%
# Unfreeze the layers [173:]
for layer in iv3_model.layers[:173]:
    layer.trainable = False
for layer in iv3_model.layers[173:]:
    layer.trainable = True
    
iv3_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
iv3_checkpointer = ModelCheckpoint(filepath='weights.best.iv3.flowers.hdf5', 
                                   verbose=2, save_best_only=True)

# %%
iv3_history_unfreeze = iv3_model.fit_generator(data_generator.flow(x_train, c_y_train, batch_size=64),
                                               steps_per_epoch = 150, epochs = 5, verbose=2, 
                                               validation_data = (x_test, c_y_test), 
                                               callbacks=[iv3_checkpointer])
# Out:
# Epoch 1/5
# Epoch 00000: val_loss improved from inf to 1.26872, saving model to weights.best.iv3.flowers.hdf5
# 1388s - loss: 0.3874 - acc: 0.9609 - val_loss: 1.2687 - val_acc: 0.9048
# Epoch 2/5
# Epoch 00001: val_loss improved from 1.26872 to 0.60318, saving model to weights.best.iv3.flowers.hdf5
# 1305s - loss: 0.1473 - acc: 0.9899 - val_loss: 0.6032 - val_acc: 0.9048
# Epoch 3/5
# Epoch 00002: val_loss improved from 0.60318 to 0.45332, saving model to weights.best.iv3.flowers.hdf5
# 1342s - loss: 0.0974 - acc: 0.9928 - val_loss: 0.4533 - val_acc: 0.9048
# Epoch 4/5
# Epoch 00003: val_loss did not improve
# 1180s - loss: 0.1689 - acc: 0.9885 - val_loss: 14.5830 - val_acc: 0.0952
# Epoch 5/5
# Epoch 00004: val_loss did not improve
# 1334s - loss: 0.2842 - acc: 0.9804 - val_loss: 0.7001 - val_acc: 0.8095

# %%
iv3_model.load_weights('weights.best.iv3.flowers.hdf5')
iv3_test_scores = iv3_model.evaluate(x_test, c_y_test)
print("Accuracy: %.2f%%" % (iv3_test_scores[1]*100))
# Out:
# 21/21 [==============================] - 1s
# Accuracy: 90.48%

# %% [markdown]
# [Kaggle. The Dataset of Flower Images](https://www.kaggle.com/olgabelitskaya/the-dataset-of-flower-images)
