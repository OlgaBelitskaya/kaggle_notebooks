# %% [markdown]
# # &#x1F4D1; &nbsp;  Image Generator of Letters
# ## Libraries

# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron|Roboto');
# body {background-color: gainsboro;}
# a {color: #39d4be; font-family: 'Roboto';}
# h1 {color: #37c9e1; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h2, h3 {color: slategray; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h4 {color: #39d4be; font-family: 'Roboto';}
# span {text-shadow: 4px 4px 4px #ccc;}
# div.output_prompt {color: #39d4be;}
# div.output_area pre, div.output_subarea {color: slategrey;}
# div.input_prompt {color: #37c9e1;}
# div.output_stderr pre {background-color: gainsboro;}
# div.output_stderr {background-color: slategrey;}
# </style>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron|Roboto');
# body {background-color: gainsboro;}
# a {color: #39d4be; font-family: 'Roboto';}
# h1 {color: #37c9e1; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h2, h3 {color: slategray; font-family: 'Orbitron'; text-shadow: 4px 4px 4px #ccc;}
# h4 {color: #39d4be; font-family: 'Roboto';}
# span {text-shadow: 4px 4px 4px #ccc;}
# div.output_prompt {color: #39d4be;}
# div.output_area pre, div.output_subarea {color: slategrey;}
# div.input_prompt {color: #37c9e1;}
# div.output_stderr pre {background-color: gainsboro;}
# div.output_stderr {background-color: slategrey;}
# </style>

# %%
import numpy as np 
import pandas as pd
import math
from scipy import misc
from collections import namedtuple

import cv2
from PIL import ImageFile, Image
from tqdm import tqdm
from glob import glob

from keras.preprocessing import image as keras_image
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tflearn

from keras.layers import Input, Dense, Reshape
from keras.layers import Activation, LeakyReLU, BatchNormalization, Flatten
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D, Conv2DTranspose
from keras.models import Sequential
from keras.optimizers import Adam, Nadam
from keras import backend

from tflearn.data_utils import build_hdf5_image_dataset

from matplotlib import rcParams
import matplotlib.pyplot as plt
import matplotlib.image as plt_image
from matplotlib import cm

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Dataset

# %%
# Function for processing an image
def image_to_tensor(img_path, folder_path):
    img = keras_image.load_img(folder_path + img_path, target_size=(32, 32))
    x = keras_image.img_to_array(img)
    return np.expand_dims(x, axis=0)
# Function for creating the data tensor
def data_to_tensor(img_paths, folder_path):
    list_of_tensors = [image_to_tensor(img_path, folder_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Load the data
data = pd.read_csv("/Users/olgabelitskaya/deep_learning_projects/DL_PP2/data2/letters2.csv")

files = data['file']
letters = data['letter']
tensors = data_to_tensor(files, "/Users/olgabelitskaya/deep_learning_projects/DL_PP2/data2/");
# Out:
# 100%|██████████| 5940/5940 [02:54<00:00, 33.97it/s]

# %%
# Print the shape 
print ('Tensor shape:', tensors.shape)
# Out:
# Tensor shape: (5940, 32, 32, 3)

# %%
# Normalize the tensors
tensors = tensors.astype('float32')/255

# %%
# Display an example
print('Label: ', letters[2000])
plt.figure(figsize=(3,3))
plt.imshow(tensors[2000]);
# Out:
# Label:  к

# %%
# Create grayscale negative tensors
gray_tensors = 1 - np.dot(tensors[...,:3], [0.299, 0.587, 0.114])
gray_tensors = gray_tensors.reshape(-1, 32*32)
print ('Grayscaled tensor shape:', gray_tensors.shape)
# Out:
# Grayscaled tensor shape: (5940, 1024)

# %%
# Display an example
print('Label: ', letters[2000])
plt.figure(figsize=(3,3))
plt.imshow(gray_tensors[2000].reshape(32, 32), cmap=cm.bone);
# Out:
# Label:  к

# %%
# Create random images
def latent_samples(n_samples, sample_size):
    return np.random.normal(loc=0, scale=1, size=(n_samples, sample_size))
latent_sample_1024 = latent_samples(1, 1024)
latent_sample_128 = latent_samples(1, 128)

# %%
# Display an example
plt.figure(figsize=(3,3))
plt.imshow(np.squeeze(latent_sample_1024).reshape(32, 32), cmap=cm.bone);

# %%
X_train_real, X_test_real = train_test_split(gray_tensors, test_size = 0.1)
X_train_real.shape, X_test_real.shape
# Out:
# ((5346, 1024), (594, 1024))

# %%
def preprocess(x):    
    x = (x - 0.25) * 2
    x = np.clip(x, -1, 1)
    return x
def deprocess(x):
    x = (x / 2 + 0.5) * 255
    x = np.clip(x, 0, 255)
    x = np.uint8(x)
    x = x.reshape(32, 32)
    return x

# %%
X_train_real = preprocess(X_train_real)
X_test_real  = preprocess(X_test_real)

# %%
def display_images(generated_images):
    n_images = len(generated_images)
    rows = 4
    cols = n_images//rows
    
    plt.figure(figsize=(cols, rows))
    for i in range(n_images):
        img = deprocess(generated_images[i])
        plt.subplot(rows, cols, i+1)
        plt.imshow(img, cmap=cm.bone)
        plt.xticks([])
        plt.yticks([])
    plt.tight_layout()
    plt.show();

# %%
display_images(X_train_real[:32])

# %% [markdown]
# ## Keras GAN
# [`"Using GAN for Generating Hand-written Digit Images" by Naoki Shibuya`](https://github.com/naokishibuya/deep-learning/blob/master/python/gan_mnist.ipynb)

# %%
discriminator = Sequential([Dense(128, input_shape=(1024,)),
                            LeakyReLU(alpha=0.01),
                            Dense(1),
                            Activation('sigmoid')], 
                           name='discriminator')

discriminator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 128)               131200
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 129
# _________________________________________________________________
# activation_11 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 131,329
# Trainable params: 131,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(3,3))
plt.title(discriminator.predict(X_train_real[1000].reshape(1, 1024)))
plt.imshow(X_train_real[1000].reshape(32, 32), cmap=cm.bone);

# %%
plt.figure(figsize=(3,3))
plt.title(discriminator.predict(latent_sample_1024))
plt.imshow(np.squeeze(latent_sample_1024).reshape(32, 32), cmap=cm.bone);

# %%
generator = Sequential([Dense(1024, input_shape=(128,)),
                        LeakyReLU(alpha=0.01),
                        Dense(1024),
                        Activation('tanh')], 
                       name='generator')

generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 1024)              132096
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# activation_12 (Activation)   (None, 1024)              0
# =================================================================
# Total params: 1,181,696
# Trainable params: 1,181,696
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(3,3))
generated_latent_sample = generator.predict(latent_sample_128)
plt.title(discriminator.predict(generated_latent_sample))
plt.imshow(generated_latent_sample.reshape(32, 32), cmap=cm.bone);

# %%
gan = Sequential([generator,discriminator])
gan.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator (Sequential)       (None, 1024)              1181696
# _________________________________________________________________
# discriminator (Sequential)   (None, 1)                 131329
# =================================================================
# Total params: 1,313,025
# Trainable params: 1,313,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
def trainable(model, trainable):
    for layer in model.layers:
        layer.trainable = trainable

# %%
def simple_GAN(sample_size, 
               g_hidden_size, 
               d_hidden_size, 
               leaky_alpha, 
               g_learning_rate,
               d_learning_rate):
    
    backend.clear_session()
    
    generator = Sequential([Dense(g_hidden_size, input_shape=(sample_size,)),
                            LeakyReLU(alpha=leaky_alpha),
                            Dense(1024), Activation('tanh')], 
                           name='generator')    

    discriminator = Sequential([Dense(d_hidden_size, input_shape=(1024,)),
                                LeakyReLU(alpha=leaky_alpha),
                                Dense(1),
                                Activation('sigmoid')], 
                               name='discriminator')    
    
    gan = Sequential([generator, discriminator])
    
    discriminator.compile(optimizer=Adam(lr=d_learning_rate), loss='binary_crossentropy')
    gan.compile(optimizer=Adam(lr=g_learning_rate), loss='binary_crossentropy')
    
    return gan, generator, discriminator

# %%
def real_fake_labels(size):
    return np.ones([size, 1]), np.zeros([size, 1])

# %%
y_real5, y_fake5 = real_fake_labels(5)
print('Real\n', y_real5)
print('Fake\n', y_fake5)
# Out:
# Real
#  [[ 1.]
#  [ 1.]
#  [ 1.]
#  [ 1.]
#  [ 1.]]
# Fake
#  [[ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]

# %%
sample_size     = 128     
g_hidden_size   = 1024     # generator
d_hidden_size   = 128     # discriminator
leaky_alpha     = 0.01
g_learning_rate = 0.0002  # generator
d_learning_rate = 0.002   # discriminator
epochs          = 500
batch_size      = 64      
valid_size      = 16     
smooth          = 0.1

# %%
y_train_real, y_train_fake = real_fake_labels(batch_size)
y_valid_real,  y_valid_fake  = real_fake_labels(valid_size)

gan, generator, discriminator = simple_GAN(sample_size, 
                                           g_hidden_size, 
                                           d_hidden_size, 
                                           leaky_alpha, 
                                           g_learning_rate,
                                           d_learning_rate)

# %%
losses = []
for e in range(epochs):
    for i in range(len(X_train_real)//batch_size):
        # real MNIST digit images
        X_batch_real = X_train_real[i*batch_size:(i+1)*batch_size]
        
        # latent samples and the generated digit images
        batch_latent_samples = latent_samples(batch_size, sample_size)
        X_batch_fake = generator.predict_on_batch(batch_latent_samples)
        
        # train the discriminator to detect real and fake images
        trainable(discriminator, True)
        discriminator.train_on_batch(X_batch_real, y_train_real * (1 - smooth))
        discriminator.train_on_batch(X_batch_fake, y_train_fake)

        # train the generator via GAN
        trainable(discriminator, False)
        gan.train_on_batch(batch_latent_samples, y_train_real)
    
    # evaluate
    X_valid_real = X_test_real[np.random.choice(len(X_test_real), valid_size, replace=False)]
    
    valid_latent_samples = latent_samples(valid_size, sample_size)
    X_valid_fake = generator.predict_on_batch(valid_latent_samples)

    d_loss  = discriminator.test_on_batch(X_valid_real, y_valid_real)
    d_loss += discriminator.test_on_batch(X_valid_fake, y_valid_fake)
    g_loss  = gan.test_on_batch(valid_latent_samples, y_valid_real) 
    
    losses.append((d_loss, g_loss))
    
    if (e+1)%50==0:
        print("Epoch: {:>3}/{} | Discriminator Loss: {:>6.4f} | Generator Loss: {:>6.4f} | DL > GL: {}"\
              .format(e+1, epochs, d_loss, g_loss, d_loss>g_loss))
    
generator.save('letter_generator.h5')
# Out:
# Epoch:   1/500 | Discriminator Loss: 0.2244 | Generator Loss: 4.2092 | DL > GL: False
# Epoch:   2/500 | Discriminator Loss: 0.1750 | Generator Loss: 4.8875 | DL > GL: False
# Epoch:   3/500 | Discriminator Loss: 0.1419 | Generator Loss: 5.5603 | DL > GL: False
# Epoch:   4/500 | Discriminator Loss: 0.1546 | Generator Loss: 6.4477 | DL > GL: False
# Epoch:   5/500 | Discriminator Loss: 0.1320 | Generator Loss: 6.3325 | DL > GL: False
# Epoch:   6/500 | Discriminator Loss: 0.1335 | Generator Loss: 10.2871 | DL > GL: False
# Epoch:   7/500 | Discriminator Loss: 0.1186 | Generator Loss: 10.7791 | DL > GL: False
# Epoch:   8/500 | Discriminator Loss: 0.1485 | Generator Loss: 10.3296 | DL > GL: False
# Epoch:   9/500 | Discriminator Loss: 0.3250 | Generator Loss: 1.6068 | DL > GL: False
# Epoch:  10/500 | Discriminator Loss: 0.4375 | Generator Loss: 1.3554 | DL > GL: False
# Epoch:  11/500 | Discriminator Loss: 0.4385 | Generator Loss: 2.1461 | DL > GL: False
# Epoch:  12/500 | Discriminator Loss: 0.6748 | Generator Loss: 1.9135 | DL > GL: False
# Epoch:  13/500 | Discriminator Loss: 0.1222 | Generator Loss: 3.8731 | DL > GL: False
# Epoch:  14/500 | Discriminator Loss: 1.5422 | Generator Loss: 1.4954 | DL > GL: True
# Epoch:  15/500 | Discriminator Loss: 1.0180 | Generator Loss: 1.0076 | DL > GL: True
# Epoch:  16/500 | Discriminator Loss: 0.7749 | Generator Loss: 1.6283 | DL > GL: False
# Epoch:  17/500 | Discriminator Loss: 0.5984 | Generator Loss: 1.8235 | DL > GL: False
# Epoch:  18/500 | Discriminator Loss: 0.1958 | Generator Loss: 2.7583 | DL > GL: False
# Epoch:  19/500 | Discriminator Loss: 0.7524 | Generator Loss: 2.6865 | DL > GL: False
# Epoch:  20/500 | Discriminator Loss: 0.4411 | Generator Loss: 1.7217 | DL > GL: False
# Epoch:  21/500 | Discriminator Loss: 3.9184 | Generator Loss: 5.9612 | DL > GL: False
# Epoch:  22/500 | Discriminator Loss: 0.5556 | Generator Loss: 1.9105 | DL > GL: False
# Epoch:  23/500 | Discriminator Loss: 0.9013 | Generator Loss: 1.7794 | DL > GL: False
# Epoch:  24/500 | Discriminator Loss: 1.5460 | Generator Loss: 0.9813 | DL > GL: True
# Epoch:  25/500 | Discriminator Loss: 1.4007 | Generator Loss: 2.0172 | DL > GL: False
# Epoch:  26/500 | Discriminator Loss: 0.8105 | Generator Loss: 2.5515 | DL > GL: False
# Epoch:  27/500 | Discriminator Loss: 1.1178 | Generator Loss: 1.5156 | DL > GL: False
# Epoch:  28/500 | Discriminator Loss: 0.4764 | Generator Loss: 1.6920 | DL > GL: False
# Epoch:  29/500 | Discriminator Loss: 1.2129 | Generator Loss: 1.2308 | DL > GL: False
# Epoch:  30/500 | Discriminator Loss: 0.5895 | Generator Loss: 1.5831 | DL > GL: False
# Epoch:  31/500 | Discriminator Loss: 0.9373 | Generator Loss: 1.1348 | DL > GL: False
# Epoch:  32/500 | Discriminator Loss: 0.8149 | Generator Loss: 1.3835 | DL > GL: False
# Epoch:  33/500 | Discriminator Loss: 0.8761 | Generator Loss: 1.6146 | DL > GL: False
# Epoch:  34/500 | Discriminator Loss: 0.7456 | Generator Loss: 1.8983 | DL > GL: False
# Epoch:  35/500 | Discriminator Loss: 0.7008 | Generator Loss: 1.5026 | DL > GL: False
# Epoch:  36/500 | Discriminator Loss: 0.9360 | Generator Loss: 1.9737 | DL > GL: False
# Epoch:  37/500 | Discriminator Loss: 1.5010 | Generator Loss: 0.7375 | DL > GL: True
# Epoch:  38/500 | Discriminator Loss: 1.1872 | Generator Loss: 1.3675 | DL > GL: False
# Epoch:  39/500 | Discriminator Loss: 1.1599 | Generator Loss: 0.9465 | DL > GL: True
# Epoch:  40/500 | Discriminator Loss: 1.7175 | Generator Loss: 0.5096 | DL > GL: True
# Epoch:  41/500 | Discriminator Loss: 0.6236 | Generator Loss: 2.0083 | DL > GL: False
# Epoch:  42/500 | Discriminator Loss: 2.5162 | Generator Loss: 3.8247 | DL > GL: False
# Epoch:  43/500 | Discriminator Loss: 0.9528 | Generator Loss: 1.2713 | DL > GL: False
# Epoch:  44/500 | Discriminator Loss: 1.2842 | Generator Loss: 0.6160 | DL > GL: True
# Epoch:  45/500 | Discriminator Loss: 2.0829 | Generator Loss: 0.6899 | DL > GL: True
# Epoch:  46/500 | Discriminator Loss: 1.2542 | Generator Loss: 0.8766 | DL > GL: True
# Epoch:  47/500 | Discriminator Loss: 2.0622 | Generator Loss: 0.6637 | DL > GL: True
# Epoch:  48/500 | Discriminator Loss: 2.7184 | Generator Loss: 4.2150 | DL > GL: False
# Epoch:  49/500 | Discriminator Loss: 1.1285 | Generator Loss: 1.8526 | DL > GL: False
# Epoch:  50/500 | Discriminator Loss: 1.7933 | Generator Loss: 0.3492 | DL > GL: True
# Epoch:  51/500 | Discriminator Loss: 2.4579 | Generator Loss: 1.0588 | DL > GL: True
# Epoch:  52/500 | Discriminator Loss: 2.4898 | Generator Loss: 0.8428 | DL > GL: True
# Epoch:  53/500 | Discriminator Loss: 1.1046 | Generator Loss: 1.1079 | DL > GL: False
# Epoch:  54/500 | Discriminator Loss: 1.0041 | Generator Loss: 0.8743 | DL > GL: True
# Epoch:  55/500 | Discriminator Loss: 0.5350 | Generator Loss: 1.5458 | DL > GL: False
# Epoch:  56/500 | Discriminator Loss: 0.9556 | Generator Loss: 2.7589 | DL > GL: False
# Epoch:  57/500 | Discriminator Loss: 1.3325 | Generator Loss: 1.2079 | DL > GL: True
# Epoch:  58/500 | Discriminator Loss: 1.2340 | Generator Loss: 0.7060 | DL > GL: True
# Epoch:  59/500 | Discriminator Loss: 1.1748 | Generator Loss: 1.0755 | DL > GL: True
# Epoch:  60/500 | Discriminator Loss: 2.0604 | Generator Loss: 3.2663 | DL > GL: False
# Epoch:  61/500 | Discriminator Loss: 2.0923 | Generator Loss: 3.4886 | DL > GL: False
# Epoch:  62/500 | Discriminator Loss: 2.2153 | Generator Loss: 0.3576 | DL > GL: True
# Epoch:  63/500 | Discriminator Loss: 0.7398 | Generator Loss: 1.2530 | DL > GL: False
# Epoch:  64/500 | Discriminator Loss: 1.1519 | Generator Loss: 0.9901 | DL > GL: True
# Epoch:  65/500 | Discriminator Loss: 2.4115 | Generator Loss: 0.7956 | DL > GL: True
# Epoch:  66/500 | Discriminator Loss: 0.8638 | Generator Loss: 1.4885 | DL > GL: False
# Epoch:  67/500 | Discriminator Loss: 1.3425 | Generator Loss: 0.8263 | DL > GL: True
# Epoch:  68/500 | Discriminator Loss: 1.5094 | Generator Loss: 2.0602 | DL > GL: False
# Epoch:  69/500 | Discriminator Loss: 1.2101 | Generator Loss: 0.9956 | DL > GL: True
# Epoch:  70/500 | Discriminator Loss: 4.2079 | Generator Loss: 0.1497 | DL > GL: True
# Epoch:  71/500 | Discriminator Loss: 1.3219 | Generator Loss: 1.3926 | DL > GL: False
# Epoch:  72/500 | Discriminator Loss: 1.0552 | Generator Loss: 1.1873 | DL > GL: False
# Epoch:  73/500 | Discriminator Loss: 1.0242 | Generator Loss: 2.5673 | DL > GL: False
# Epoch:  74/500 | Discriminator Loss: 2.1032 | Generator Loss: 0.6815 | DL > GL: True
# Epoch:  75/500 | Discriminator Loss: 1.2836 | Generator Loss: 1.2529 | DL > GL: True
# Epoch:  76/500 | Discriminator Loss: 1.2916 | Generator Loss: 1.3484 | DL > GL: False
# Epoch:  77/500 | Discriminator Loss: 1.1006 | Generator Loss: 0.7185 | DL > GL: True
# Epoch:  78/500 | Discriminator Loss: 0.6593 | Generator Loss: 1.5186 | DL > GL: False
# Epoch:  79/500 | Discriminator Loss: 1.2864 | Generator Loss: 1.3174 | DL > GL: False
# Epoch:  80/500 | Discriminator Loss: 4.5416 | Generator Loss: 0.2341 | DL > GL: True
# Epoch:  81/500 | Discriminator Loss: 0.7462 | Generator Loss: 1.4701 | DL > GL: False
# Epoch:  82/500 | Discriminator Loss: 0.7567 | Generator Loss: 1.4014 | DL > GL: False
# Epoch:  83/500 | Discriminator Loss: 1.4743 | Generator Loss: 0.8898 | DL > GL: True
# Epoch:  84/500 | Discriminator Loss: 1.1491 | Generator Loss: 0.9523 | DL > GL: True
# Epoch:  85/500 | Discriminator Loss: 1.4583 | Generator Loss: 0.6547 | DL > GL: True
# Epoch:  86/500 | Discriminator Loss: 2.0922 | Generator Loss: 0.6001 | DL > GL: True
# Epoch:  87/500 | Discriminator Loss: 1.3358 | Generator Loss: 0.7963 | DL > GL: True
# Epoch:  88/500 | Discriminator Loss: 1.4548 | Generator Loss: 0.7453 | DL > GL: True
# Epoch:  89/500 | Discriminator Loss: 0.7864 | Generator Loss: 1.4117 | DL > GL: False
# Epoch:  90/500 | Discriminator Loss: 1.3079 | Generator Loss: 1.4537 | DL > GL: False
# Epoch:  91/500 | Discriminator Loss: 1.4092 | Generator Loss: 1.7180 | DL > GL: False
# Epoch:  92/500 | Discriminator Loss: 1.3206 | Generator Loss: 1.5566 | DL > GL: False
# Epoch:  93/500 | Discriminator Loss: 1.2405 | Generator Loss: 1.3144 | DL > GL: False
# Epoch:  94/500 | Discriminator Loss: 1.0657 | Generator Loss: 1.7252 | DL > GL: False
# Epoch:  95/500 | Discriminator Loss: 0.8506 | Generator Loss: 1.8513 | DL > GL: False
# Epoch:  96/500 | Discriminator Loss: 1.5873 | Generator Loss: 1.7184 | DL > GL: False
# Epoch:  97/500 | Discriminator Loss: 1.5796 | Generator Loss: 0.6792 | DL > GL: True
# Epoch:  98/500 | Discriminator Loss: 1.7975 | Generator Loss: 1.2215 | DL > GL: True
# Epoch: 477/500 | Discriminator Loss: 1.2820 | Generator Loss: 1.3454 | DL > GL: False
# Epoch: 478/500 | Discriminator Loss: 1.1468 | Generator Loss: 0.9923 | DL > GL: True
# Epoch: 479/500 | Discriminator Loss: 1.0173 | Generator Loss: 1.1321 | DL > GL: False
# Epoch: 480/500 | Discriminator Loss: 2.1141 | Generator Loss: 1.2124 | DL > GL: True
# Epoch: 481/500 | Discriminator Loss: 1.7161 | Generator Loss: 1.1392 | DL > GL: True
# Epoch: 482/500 | Discriminator Loss: 1.7048 | Generator Loss: 1.4555 | DL > GL: True
# Epoch: 483/500 | Discriminator Loss: 1.1977 | Generator Loss: 1.2707 | DL > GL: False
# Epoch: 484/500 | Discriminator Loss: 1.2874 | Generator Loss: 0.8209 | DL > GL: True
# Epoch: 485/500 | Discriminator Loss: 0.9484 | Generator Loss: 0.9386 | DL > GL: True
# Epoch: 486/500 | Discriminator Loss: 1.0926 | Generator Loss: 0.7955 | DL > GL: True
# Epoch: 487/500 | Discriminator Loss: 1.5064 | Generator Loss: 0.7313 | DL > GL: True
# Epoch: 488/500 | Discriminator Loss: 1.2919 | Generator Loss: 1.2131 | DL > GL: True
# Epoch: 489/500 | Discriminator Loss: 1.4068 | Generator Loss: 1.4510 | DL > GL: False
# Epoch: 490/500 | Discriminator Loss: 1.3692 | Generator Loss: 1.6770 | DL > GL: False
# Epoch: 491/500 | Discriminator Loss: 1.2954 | Generator Loss: 1.1161 | DL > GL: True
# Epoch: 492/500 | Discriminator Loss: 1.4483 | Generator Loss: 1.9623 | DL > GL: False
# Epoch: 493/500 | Discriminator Loss: 1.4829 | Generator Loss: 0.6888 | DL > GL: True
# Epoch: 494/500 | Discriminator Loss: 0.9373 | Generator Loss: 0.9101 | DL > GL: True
# Epoch: 495/500 | Discriminator Loss: 1.5396 | Generator Loss: 0.8944 | DL > GL: True
# Epoch: 496/500 | Discriminator Loss: 1.9560 | Generator Loss: 1.6201 | DL > GL: True
# Epoch: 497/500 | Discriminator Loss: 1.4175 | Generator Loss: 0.8811 | DL > GL: True
# Epoch: 498/500 | Discriminator Loss: 1.4061 | Generator Loss: 1.0525 | DL > GL: True
# Epoch: 499/500 | Discriminator Loss: 2.3779 | Generator Loss: 0.5320 | DL > GL: True
# Epoch: 500/500 | Discriminator Loss: 0.9703 | Generator Loss: 1.0526 | DL > GL: False

# %%
def display_loss(losses):
    losses = np.array(losses)    
    
    plt.figure(figsize=(18, 6))
    plt.plot(losses.T[0], '-o', c='#37c9e1', lw=1, label='Discriminator')
    plt.plot(losses.T[1], '-o', c='#39d4be', lw=1, label='Generator')
    plt.title("Training Loss Functions")
    plt.legend();

# %%
display_loss(losses)

# %%
latent_examples = latent_samples(32, sample_size)
generated_letters = generator.predict(latent_examples)
display_images(generated_letters)

# %% [markdown]
# ## Keras DCGAN
# [`"Deep Convolutional GAN (DCGAN) with MNIST" by Naoki Shibuya`](https://github.com/naokishibuya/deep-learning/blob/master/python/dcgan_mnist.ipynb)

# %%
X_train_real = X_train_real.reshape(-1, 32, 32, 1)
X_test_real = X_test_real.reshape(-1, 32, 32, 1)
