# %%
import plotly.graph_objects as go
import numpy as np,pandas as pd
import plotly.express as px

# %% [markdown]
# ## Interactive Examples

# %%
t=np.linspace(0,2*np.pi,3600) 
fig=go.Figure(); steps=[]
for step in np.arange(1,41,4):
    f=np.cos(14*t)+np.cos(6*t)
    fig.add_trace(go.Scatter(
            visible=False,name="k="+str(step),
            line=dict(color='rgb(.7,0,%f)'%(step/41),width=2),
            x=f*np.cos(step*t),y=f*np.sin(step*t)))
fig.data[0].visible=True
st="x=(cos(14t)+sin(6t))cos(kt) \n"+\
   "y=(cos(14t)+sin(6t))sin(kt)"
for i in range(len(fig.data)):
    step=dict(method="update",
              args=[{"visible":[False]*len(fig.data)}])
    step["args"][0]["visible"][i]=True
    steps.append(step)
sliders=[dict(active=10,pad={"t":20},steps=steps)]
fig.update_layout(width=500,height=550,sliders=sliders,
                  template='plotly_dark',
                  title_text=st,title_font=dict(size=15))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="e7771c93-d678-4020-938c-a42fc3e79929" class="plotly-graph-div" style="height:550px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7771c93-d678-4020-938c-a42fc3e79929")) {
#                     Plotly.newPlot(
#                         'e7771c93-d678-4020-938c-a42fc3e79929',
#                         [{"line": {"color": "rgb(.7,0,0.024390)", "width": 2}, "name": "k=1", "type": "scatter", "visible": true, "x": [2.0, 1.999643415445256, 1.9985738526887182, 1.9967918843377532, 1.9942984643523218, 1.991094927466761, 1.987182988380789, 1.9825647407202416, 1.9772426557682021, 1.9712195809673172, 1.9644987381942496, 1.9570837218073525, 1.9489784964688002, 1.940187394742547, 1.930715114469627, 1.9205667159224573, 1.9097476187399325, 1.8982635986452443, 1.8861207839485024, 1.8733256518363528, 1.8598850244509393, 1.8458060647606795, 1.831096272225457, 1.8157634782589611, 1.7998158414910415, 1.783261842833051, 1.7661102803493025, 1.7483702639378562, 1.7300512098239995, 1.7111628348698842, 1.6917151507039059, 1.6717184576735231, 1.6511833386253278, 1.6301206525162761, 1.6085415278601127, 1.5864573560131023, 1.5638797843033059, 1.5408207090077157, 1.5172922681816743, 1.4933068343450866, 1.4688770070300254, 1.4440156051944149, 1.418735659506567, 1.3930504045054157, 1.3669732706413824, 1.3405178762028647, 1.3136980191334326, 1.2865276687448615, 1.2590209573312119, 1.2311921716892167, 1.203055744550303, 1.1746262459296215, 1.1459183743975072, 1.116946948278856, 1.087726896785924, 1.0582732510901118, 1.028601135338332, 0.9987257576195808, 0.9686624008873735, 0.9384264138437296, 0.9080332017904064, 0.8774982174531064, 0.846836951784403, 0.8160649247511195, 0.7851976761119335, 0.7542507561909555, 0.7232397166530486, 0.6921801012866446, 0.6610874367998021, 0.6299772236352539, 0.5988649268101573, 0.5677659667862629, 0.5366957103761788, 0.5056694616913915, 0.47470245313767234, 0.44380983646346633, 0.4130066738668248, 0.3823079291663981, 0.3517284590419712, 0.3212830043499662, 0.29098618151930133, 0.26085247403292167, 0.23089622400027562, 0.201131623825953, 0.17157
class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b8aaed7-bc6a-4e9f-81be-431889f157a9")) {
#                     Plotly.newPlot(
#                         '1b8aaed7-bc6a-4e9f-81be-431889f157a9',
#                         [{"alignmentgroup": "True", "hovertemplate": "color=Fresh<br>x=%{x}<br>Customer 1=%{text}<extra></extra>", "legendgroup": "Fresh", "marker": {"color": "#636efa"}, "name": "Fresh", "offsetgroup": "Fresh", "orientation": "v", "showlegend": true, "text": [26373.0], "textposition": "outside", "texttemplate": "%{text:d}", "type": "bar", "x": ["Fresh"], "xaxis": "x", "y": [26373], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Milk<br>x=%{x}<br>Customer 1=%{text}<extra></extra>", "legendgroup": "Milk", "marker": {"color": "#EF553B"}, "name": "Milk", "offsetgroup": "Milk", "orientation": "v", "showlegend": true, "text": [36423.0], "textposition": "outside", "texttemplate": "%{text:d}", "type": "bar", "x": ["Milk"], "xaxis": "x", "y": [36423], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Grocery<br>x=%{x}<br>Customer 1=%{text}<extra></extra>", "legendgroup": "Grocery", "marker": {"color": "#00cc96"}, "name": "Grocery", "offsetgroup": "Grocery", "orientation": "v", "showlegend": true, "text": [22019.0], "textposition": "outside", "texttemplate": "%{text:d}", "type": "bar", "x": ["Grocery"], "xaxis": "x", "y": [22019], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Frozen<br>x=%{x}<br>Customer 1=%{text}<extra></extra>", "legendgroup": "Frozen", "marker": {"color": "#ab63fa"}, "name": "Frozen", "offsetgroup": "Frozen", "orientation": "v", "showlegend": true, "text": [5154.0], "textposition": "outside", "texttemplate": "%{text:d}", "type": "bar", "x": ["Frozen"], "xaxis": "x", "y": [5154], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Detergents_Paper<br>x=%{x}<br>Customer 1=%{text}<extra></extra>", "legendgroup": "Detergents_Paper", "marker": {"color": "#FFA15A"}, "name": "Detergents_Paper", "offsetgroup": "Detergents_Paper", "orientation": "v", "showlegend": true, "text": [4337.0], "textposition": "outside", "texttemplate": "%{text:d}", "type": "bar", "x": ["Detergents_Paper"], "xaxis": "x", "y": [4337], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "color=Delicatessen<br>x=%{x}<br>Customer 1=%{text}<extra></extra>", "legendgroup": "Delicatessen", "marker": {"color": "#19d3f3"}, "name": "Delicatessen", "offsetgroup": "Delicatessen", "orientation": "v", "showlegend": true, "text": [16523.0], "textposition": "outside", "texttemplate": "%{text:d}", "type": "bar", "x": ["Delicatessen"], "xaxis": "x", "y": [16523], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"title": {"text": "color"}, "tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpol ...

# %%
pdata=[go.Bar(name=df.columns[i],
              x=df.index,y=df.iloc[:,i])
       for i in range(3)]
fig=go.Figure(pdata)
fig.update_layout(width=500,height=500,barmode='stack',
                  template='plotly_white')
fig.show()
# Out:
# <div>
#
#
#             <div id="2805fcfc-9468-48e2-97c0-29c79d410f4d" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2805fcfc-9468-48e2-97c0-29c79d410f4d")) {
#                     Plotly.newPlot(
#                         '2805fcfc-9468-48e2-97c0-29c79d410f4d',
#                         [{"name": "Customer 1", "type": "bar", "x": ["Fresh", "Milk", "Grocery", "Frozen", "Detergents_Paper", "Delicatessen"], "y": [26373, 36423, 22019, 5154, 4337, 16523]}, {"name": "Customer 2", "type": "bar", "x": ["Fresh", "Milk", "Grocery", "Frozen", "Detergents_Paper", "Delicatessen"], "y": [16165, 4230, 7595, 201, 4003, 57]}, {"name": "Customer 3", "type": "bar", "x": ["Fresh", "Milk", "Grocery", "Frozen", "Detergents_Paper", "Delicatessen"], "y": [14276, 803, 3045, 485, 100, 518]}],
#                         {"barmode": "stack", "height": 500, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "#C8D4E3", "linecolor": "#C8D4E3", "minorgridcolor": "#C8D4E3", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "s ...

# %% [markdown]
# ## 3D Plotting

# %%
a,b=np.random.randint(1,3),np.random.randint(3,5)
c,d=np.random.randint(2,4),np.random.randint(10,12)
e,f=np.random.randint(13,18),np.random.randint(1,3)
t=np.linspace(0,2*np.pi,60); r=[-1,0,1]
fx=-d*np.cos(t)-f*np.cos(b*t)+e*np.sin(a*t)
fy=-e*np.cos(a*t)+d*np.sin(t)-f*np.sin(b*t)
fz=d*np.cos(c*t)
fig=go.Figure(data=[go.Scatter3d(z=r[k]*fz,\
x=r[i]*fx,y=r[j]*fy,marker=dict(size=1.5)) \
for i in range(3) for j in range(3) for k in range(3)])
scene=dict(xaxis=dict(title='',showticklabels=False),
           yaxis=dict(title='',showticklabels=False),
           zaxis=dict(title='',showticklabels=False))
fig.update_layout(title='3D Functions',autosize=False,
                  width=500,height=500,showlegend=False,
                  margin=dict(l=3,r=3,b=3,t=30),
                  scene=scene,template='plotly_dark')
fig.show()
# Out:
# <div>
#
#
#             <div id="ef851e54-d920-4422-a297-2785f82b6391" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ef851e54-d920-4422-a297-2785f82b6391")) {
#                     Plotly.newPlot(
#                         'ef851e54-d920-4422-a297-2785f82b6391',
#                         [{"marker": {"size": 1.5}, "type": "scatter3d", "x": [12.0, 10.170215263100715, 7.9203173018643795, 5.360209299033823, 2.642713887456015, -0.06028800738402218, -2.5850218369329125, -4.801472744856258, -6.6329834948207225, -8.06633550333828, -9.150552205570628, -9.984678956198536, -10.69676275108723, -11.417826326290534, -12.25552383299366, -13.27221978080926, -14.471439575109715, -15.79514057725298, -17.13231521307157, -18.33740855689907, -19.255274729434873, -19.7482236366147, -19.720331707178097, -19.134674943876043, -18.020403213513024, -16.46838600454167, -14.61619819220956, -12.625115410892679, -10.653212711637599, -8.829352799764568, -7.232687554499209, -5.881307831065438, -4.732038484067042, -3.69138093462489, -2.635610961061891, -1.4364012526772232, 0.012650565468554476, 1.7733705017713461, 3.8483230374645725, 6.176758107255253, 8.641955348237499, 11.08869278705942, 13.347756220688309, 15.263145355010494, 16.717148552894308, 17.648836377928845, 18.062697411485093, 18.025898399772935, 17.654680379913856, 17.092340330388215, 16.482747773906794, 15.944139600863437, 15.547882343232228, 15.30599891922213, 15.169686002781177, 15.03907946050736, 14.782510659692289, 14.261796010753107, 13.359019832521678, 12.